# %%
import pandas as pd
import numpy as np
import os
import glob
from datetime import datetime
from scipy import optimize

# %%
project_path = os.getcwd()

# %% [markdown]
# # Whole Population Run

# %%
from support_functions.data_loader import (
    load_data
)
from support_functions.analysis import (
    analyze_account_performance,
    analyze_stock_performance
)

# %%
data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
print("\n" + "="*50)
print("FIDELITY PORTFOLIO ANALYSIS")
print("="*50)

# 1. Total Portfolio Performance
total_value = positions_df['Current Value'].sum()
print(f"\n[1] Total Portfolio Value: ${total_value:,.2f}")
# Out:
# ==================================================
# FIDELITY PORTFOLIO ANALYSIS
# ==================================================
#
# [1] Total Portfolio Value: $1,289,734.62

# %%
print("\nCalculating performance for each account...")
results = analyze_account_performance(positions_df, transactions_df, latest_date)
results
# Out:
# Calculating performance for each account...
#              Account Name Account Number Symbol Asset Type  Current Value  \
# 0  Health Savings Account      241802439   None    Account        9707.44
# 1              Individual      Z23390746   None    Account     1250701.91
#
#    Total Invested  Total Return ($) Total Return (%)     IRR
# 0         8450.64           1256.80           14.87%  14.99%
# 1      1100000.00         150701.91           13.70%   9.88%

# %%
print("\nCalculating performance for Account & Symbol...")
results = analyze_stock_performance(positions_df, transactions_df, latest_date)
results.sort_values('Total Return ($)', ascending=False)
# Out:
# Calculating performance for Account & Symbol...
#    Account Name Account Number Symbol Asset Type  Current Value  \
# 0    Individual      Z23390746  FXAIX      Stock      178132.62
# 1    Individual      Z23390746  FSKAX      Stock      122961.08
# 2    Individual      Z23390746  FSPSX      Stock       76959.48
# 3    Individual      Z23390746   AAPL      Stock       19030.20
# 6    Individual      Z23390746   TSLA      Stock        8994.40
# 7    Individual      Z23390746  GOOGL      Stock        6260.00
# 10   Individual      Z23390746    AXP      Stock        3691.30
# 11   Individual      Z23390746    JPM      Stock        3222.20
# 15   Individual      Z23390746   AMZN      Stock        2308.20
# 4    Individual      Z23390746   MSFT      Stock       14508.60
# 8    Individual      Z23390746    MCD      Stock        6112.60
# 12   Individual      Z23390746   COKE      Stock        3066.00
# 5    Individual      Z23390746   BRKB      Stock       10053.00
# 18   Individual      Z23390746   NVDA      Stock        1865.00
# 9    Individual      Z23390746    GLD      Stock        3963.10
# 13   Individual      Z23390746   SBUX      Stock        2526.30
# 19   Individual      Z23390746    PEP      Stock        1435.20
# 16   Individual      Z23390746     VZ      Stock        2036.50
# 21   Individual      Z23390746   COST      Stock         862.34
# 20   Individual      Z23390746     PG      Stock        1433.10
# 17   Individual      Z23390746    NKE      Stock        1911.30
# 14   Individual      Z23390746    KHC      Stock        2425.00
#
#     Total Invested  Total Return ($) Total Return (%)      IRR
# 0        142563.94          35568.68           24.95%   22.22%
# 1        102299.89          20661.19           20.20%   16.71%
# 2         63994.40          12965.08           20.26%   17.78%
# 3         10759.99           8270.21           76.86%   19.54%
# 6          3767.50           5226.90          138.74%   57.11%
# 7          1830.00           4430.00          242.08%   54.14%
# 10         1500.00           2191.30          146.09%   32.45%
# 11         1200.00           2022.20          168.52%   37.17%
# 15          950.00           1358.20          142.97%   36.39%
# 4         13342.95           1165.65            8.74%    6.67%
# 8          5157.50            955.10           18.52%   13.83%
# 12         2175.00            891.00           40.97%  102.16%
# 5          9230.90            822.10            8.91%   11.19%
# 18         1180.00            685.00           58.05%   63.98%
# 9          3800.00            163.10            4.29%   24.90%
# 13         2453.40             72.90            2.97%    3.83%
# 19         1440.00             -4.80           -0.33%    2.96%
# 16         2100.00            -63.50           -3.02%    3.41%
# 21          980.00           -117.66          -12.01%  -22.96%
# 20         1570.00           -136.90           -8.72%  -14.87%
# 17         2580.80           -669.50          -25.94%  -12.11%
# 14         3200.00           -775.00          -24.22%  -16.59%

# %%
acct = accounts[0]

# %%
print(f"\n--- Account: {acct} ---")
acct_df = perf_df[perf_df['Account Name'] == acct].sort_values('Current Value', ascending=False)
# Out:
# --- Account: Individual ---

# %%
# Calculate Account Total Weighted
acct_val = acct_df['Current Value'].sum()
acct_return_dollar = acct_df['Total Return ($)'].sum()
acct_invested = acct_df['Total Invested'].sum()
acct_roi = (acct_return_dollar / acct_invested) if acct_invested > 0 else 0
[acct_val,acct_return_dollar,acct_invested,acct_roi]
# Out:
# [np.float64(1250701.9100000001),
#  np.float64(238080.67999999996),
#  np.float64(1074508.2999999998),
#  np.float64(0.221571745886002)]

# %%
acct_df
# Out:
#    Account Name Account Number            Symbol Asset Type  Current Value  \
# 0    Individual      Z23390746         912797SG3       Bond      199646.00
# 1    Individual      Z23390746             FXAIX      Stock      178132.62
# 2    Individual      Z23390746           FZFXX**       Cash      128390.20
# 3    Individual      Z23390746             FSKAX      Stock      122961.08
# 4    Individual      Z23390746         912797SE8       Bond       99962.00
# 5    Individual      Z23390746         912797RJ8       Bond       99872.00
# 6    Individual      Z23390746         912797SQ1       Bond       99617.00
# 7    Individual      Z23390746         912797SS7       Bond       99480.00
# 8    Individual      Z23390746         912797ST5       Bond       99408.00
# 9    Individual      Z23390746             FSPSX      Stock       76959.48
# 10   Individual      Z23390746              AAPL      Stock       19030.20
# 11   Individual      Z23390746              MSFT      Stock       14508.60
# 12   Individual      Z23390746              BRKB      Stock       10053.00
# 13   Individual      Z23390746              TSLA      Stock        8994.40
# 14   Individual      Z23390746             GOOGL      Stock        6260.00
# 15   Individual      Z23390746               MCD      Stock        6112.60
# 16   Individual      Z23390746               GLD      Stock        3963.10
# 17   Individual      Z23390746               AXP      Stock        3691.30
# 18   Individual      Z23390746               JPM      Stock        3222.20
# 19   Individual      Z23390746              COKE      Stock        3066.00
# 20   Individual      Z23390746              SBUX      Stock        2526.30
# 21   Individual      Z23390746               KHC      Stock        2425.00
# 22   Individual      Z23390746              AMZN      Stock        2308.20
# 23   Individual      Z23390746                VZ      Stock        2036.50
# 24   Individual      Z23390746               NKE      Stock        1911.30
# 25   Individual      Z23390746              NVDA      Stock        1865.00
# 26   Individual      Z23390746               PEP      Stock        1435.20
# 27   Individual      Z23390746                PG      Stock        1433.10
# 28   Individual      Z23390746              COST      Stock         862.34
# 29   Individual      Z23390746  Pending activity      Stock      -49430.81
#
#     Total Invested  Total Return ($)  Total Return (%)       IRR
# 0        199122.67            523.33          0.002628  0.036137
# 1        142563.94          38132.62          0.267477  0.222154
# 2             0.00         128390.20          0.000000  0.000000
# 3        102299.89          22961.08          0.224449  0.167138
# 4         99417.15            544.85          0.005480  0.036937
# 5         99568.33            303.67          0.003050  0.039072
# 6         99438.44            178.56          0.001796  0.033284
# 7         99442.33             37.67          0.000379  0.019945
# 8         99443.11            -35.11         -0.000353  0.000000
# 9         63994.40          16959.48          0.265015  0.177839
# 10        10759.99           8489.61          0.788998  0.195420
# 11        13342.95           1315.05          0.098558  0.066716
# 12         9230.90            822.10          0.089060  0.111919
# 13         3767.50           5226.90          1.387366  0.571119
# 14         1830.00           4458.60          2.436393  0.541373
# 15         5157.50           1184.00          0.229569  0.138307
# 16         3800.00            163.10          0.042921  0.248957
# 17         1500.00           2278.30          1.518867  0.324517
# 18         1200.00           2174.20          1.811833  0.371657
# 19         2175.00           2949.74          1.356202  1.021591
# 20         2453.40            263.30          0.107320  0.038295
# 21         3200.00           -575.00         -0.179688 -0.165863
# 22          950.00           1358.20          1.429684  0.363938
# 23         2100.00             72.64          0.034590  0.034058
# 24         2580.80           -588.20         -0.227914 -0.121120
# 25         1180.00            685.40          0.580847  0.639832
# 26         1440.00             37.21          0.025840  0.029642
# 27         1570.00           -115.76         -0.073732 -0.148653
# 28          980.00           -115.06         -0.117408 -0.229633
# 29            0.00              0.00          0.000000  0.000000
