# %%
import pandas as pd
import numpy as np
import os
import importlib
from datetime import datetime

# %%
current_path = os.path.abspath(".")

# %%
from support_functions import load_position,load_transaction

# %%
## load position
data_folder_path = os.path.abspath(os.path.join(current_path,"..",'data'))
transaction_file_pattern = 'Accounts_History_*.csv'
position_file_pattern = 'Portfolio_Positions_*.csv'

position = load_position(data_folder_path, position_file_pattern)
transactions = load_transaction(data_folder_path, transaction_file_pattern)

# %%
transactions
# Out:
#        Run Date                 Account  \
# 0    2022-07-26    Individual Z23390746
# 1    2022-07-29    Individual Z23390746
# 2    2022-07-29    Individual Z23390746
# 3    2022-08-05    Individual Z23390746
# 4    2022-08-05    Individual Z23390746
# ..          ...                     ...
# 402  2025-02-28  Health Savings Account
# 403  2025-03-03              Individual
# 404  2025-03-04              Individual
# 405  2025-03-04              Individual
# 406  2025-03-06              Individual
#
#                                                 Action     Symbol  \
# 0            Electronic Funds Transfer Received (Cash)   Transfer
# 1     REINVESTMENT FIDELITY TREASURY MONEY MARKET F...      FZFXX
# 2     DIVIDEND RECEIVED FIDELITY TREASURY MONEY MAR...      FZFXX
# 3                   YOU BOUGHT APPLE INC (AAPL) (Cash)       AAPL
# 4     YOU BOUGHT STARBUCKS CORP COM USD0.001 (SBUX)...       SBUX
# ..                                                 ...        ...
# 402   REINVESTMENT FIDELITY GOVERNMENT CASH RESERVE...      FDRXX
# 403          Electronic Funds Transfer Received (Cash)   Transfer
# 404   REDEMPTION PAYOUT UNITED STATES TREAS BILLS Z...  912797NK9
# 405          Electronic Funds Transfer Received (Cash)   Transfer
# 406   REDEMPTION PAYOUT UNITED STATES TREAS BILLS Z...  912797MM6
#
#                                            Description  Type   Quantity  \
# 0                                       No Description  Cash       0.00
# 1                  FIDELITY TREASURY MONEY MARKET FUND  Cash       0.22
# 2                  FIDELITY TREASURY MONEY MARKET FUND  Cash       0.00
# 3                                            APPLE INC  Cash       9.00
# 4                          STARBUCKS CORP COM USD0.001  Cash       1.00
# ..                                                 ...   ...        ...
# 402                  FIDELITY GOVERNMENT CASH RESERVES  Cash       5.07
# 403                                     No Description  Cash       0.00
# 404   UNITED STATES TREAS BILLS ZERO CPN 0.00000% 0...  Cash  -50000.00
# 405                                     No Description  Cash       0.00
# 406   UNITED STATES TREAS BILLS ZERO CPN 0.00000% 0...  Cash -100000.00
#
#      Price ($)  Commission ($)  Fees ($)  Accrued Interest ($)  Amount ($)  \
# 0          NaN             NaN       NaN                   NaN     1000.00
# 1         1.00             NaN       NaN                   NaN       -0.22
# 2          NaN             NaN       NaN                   NaN        0.22
# 3       164.61             NaN       NaN                   NaN    -1481.45
# 4        85.20             NaN       NaN                   NaN      -85.20
# ..         ...             ...       ...                   ...         ...
# 402       1.00             NaN       NaN                   NaN       -5.07
# 403        NaN             NaN       NaN                   NaN    25500.00
# 404       1.00             NaN       NaN                   NaN    50000.00
# 405        NaN             NaN       NaN                   NaN    24500.00
# 406       1.00             NaN       NaN                   NaN   100000.00
#
#     Settlement Date Account Number
# 0               NaT            NaN
# 1               NaT            NaN
# 2               NaT            NaN
# 3        2022-08-09            NaN
# 4        2022-08-09            NaN
# ..              ...            ...
# 402             NaT      241802439
# 403             NaT      Z23390746
# 404             NaT      Z23390746
# 405             NaT      Z23390746
# 406             NaT      Z23390746
#
# [407 rows x 14 columns]
