# %% [markdown]
# ## Start

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pathlib import Path
import os
import glob
from scipy import optimize
import importlib

# %%
project_path = Path.cwd().parent

# %% [markdown]
# ## load_data

# %% [markdown]
# ### get_latest_position_file

# %%
data_dir = f'{project_path}/data'

# %%
files = glob.glob(os.path.join(data_dir, 'Portfolio_Positions_*.csv'))
files
# Out:
# ['/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Apr-06-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Aug-05-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Nov-16-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Apr-29-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Apr-02-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_May-06-2025.csv']

# %%
latest_file = None
latest_date = None

for f in files:
    basename = os.path.basename(f)
    date_part = basename.replace('Portfolio_Positions_', '').replace('.csv', '')
    try:
        date_obj = datetime.strptime(date_part, '%b-%d-%Y')
        if latest_date is None or date_obj > latest_date:
            latest_date = date_obj
            latest_file = f
    except ValueError:
        continue
latest_date = pd.to_datetime(latest_date)
[latest_file, latest_date]
# Out:
# ['/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv',
#  Timestamp('2025-12-31 00:00:00')]

# %% [markdown]
# ### clean_positions

# %%
from support_functions.data_loader import get_latest_position_file, clean_currency

data_dir = f'{project_path}/data'
pos_file, pos_date = get_latest_position_file(data_dir)
positions_df = pd.read_csv(pos_file, index_col=False)
positions_df = positions_df.dropna(subset=['Account Name'])
cols_to_clean = [
    'Last Price', 'Current Value', 
    'Cost Basis Total', 'Today\'s Gain/Loss Dollar', 
    'Total Gain/Loss Dollar'
]

# %%
for col in cols_to_clean:
    if col in positions_df.columns:
        positions_df[col] = positions_df[col].apply(clean_currency)

# Clean Quantity (remove match for formatting issues if any)
if 'Quantity' in positions_df.columns:
    positions_df['Quantity'] = pd.to_numeric(positions_df['Quantity'], errors='coerce').fillna(0)

# %%
positions_df['Account Name'].unique()
# Out:
# array(['Individual', 'ERNST & YOUNG 401(K)',
#        'Cash Management (Individual)', 'Health Savings Account'],
#       dtype=object)

# %% [markdown]
# ### load_transactions

# %%
data_dir = f'{project_path}/data'
max_cols=14
hist_files = glob.glob(os.path.join(data_dir, 'Accounts_History_*.csv'))
transactions_dfs = []
print(f"Found {len(hist_files)} history files.")

for f in hist_files:
    df = pd.read_csv(f, header=0, usecols=range(max_cols))
    transactions_dfs.append(df)

transactions_df = pd.concat(transactions_dfs, ignore_index=True)
# Out:
# Found 4 history files.

# %%
transactions_df.columns
# Out:
# Index(['Run Date', 'Account', 'Account Number', 'Action', 'Symbol',
#        'Description', 'Type', 'Price ($)', 'Quantity', 'Commission ($)',
#        'Fees ($)', 'Accrued Interest ($)', 'Amount ($)', 'Settlement Date'],
#       dtype='object')

# %%
transactions_df['Account'].unique()
# Out:
# array(['Individual', 'Health Savings Account',
#        'Cash Management (Individual)', 'ERNST & YOUNG 401(K)', nan],
#       dtype=object)

# %%
[transactions_df.iloc[292]['Run Date'],transactions_df.iloc[228]['Run Date']]
# Out:
# ['01/31/2024', '04/25/2024']

# %% [markdown]
# ### clean_transactions

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_transactions, clean_currency
data_dir = f'{project_path}/data'
transactions_df = load_transactions(data_dir)
# Out:
# Found 4 history files.

# %%
transactions_df.columns
# Out:
# Index(['Run Date', 'Account', 'Account Number', 'Action', 'Symbol',
#        'Description', 'Type', 'Price ($)', 'Quantity', 'Commission ($)',
#        'Fees ($)', 'Accrued Interest ($)', 'Amount ($)', 'Settlement Date'],
#       dtype='object')

# %%
transactions_df['Account'].unique()
# Out:
# array(['Individual', 'Health Savings Account',
#        'Cash Management (Individual)', 'ERNST & YOUNG 401(K)', nan],
#       dtype=object)

# %%
for col in transactions_df.columns:
    if (
        (transactions_df[col].dtype == 'object' ) or 
        (transactions_df[col].dtype == 'string')
    ):
        transactions_df[col] = transactions_df[col].str.strip()   
# Standardize dates
transactions_df['Run Date'] = pd.to_datetime(transactions_df['Run Date'], errors='coerce')
# Sometimes 'Settlement Date' exists
if 'Settlement Date' in transactions_df.columns:
        transactions_df['Settlement Date'] = pd.to_datetime(transactions_df['Settlement Date'], errors='coerce')
    


# Clean numeric columns
hist_numeric_cols = [
    'Amount ($)', 'Price ($)', 'Quantity', 
    'Commission ($)', 'Fees ($)', 'Accrued Interest ($)'
]
for col in hist_numeric_cols:
    if col in transactions_df.columns:
        transactions_df[col] = transactions_df[col].apply(clean_currency)
    
# Sort by date
transactions_df = transactions_df.sort_values('Run Date')

# %%
transactions_df['Amount ($)'].unique()
# Out:
# array(['Amount ($)', '-198.36', '-3.26', '0.2', '198.36', '3.26',
#        '159.61', '40', '132.4', '308.95', '30000', '-342.04', '342.04',
#        '-1642.64', '1642.64', '-11.12', '-1065.29', '11.12', '1065.29',
#        '4.85', '35.4', '4', '-98925.69', '-2100', '24.9', '20000',
#        '-20000', '-40000', '150000', '-99486.67', '18.3', '-120.16',
#        '120.16', '-2.05', '50000', '2.05', '17.5', '-19861.24', '-3200',
#        '-29840.57', '5', '7', '105.92', '247.16', '12.5', '-211.35',
#        '211.35', '-1.7', '0.22', '1.7', '-19891.97', '-49432.51', '70000',
#        '-4600', '-49429.35', '-19926.11', '-49424.93', '-6.64', '-241.99',
#        '6.64', '241.99', '-1000', '5.33', '12.44', '11.1', '0.08',
#        '-1.27', '0.28', '-2.98', '-83.8', '83.8', '-3.44', '0.23',
#        '-29658.75', '3.44', '-29838.3', '10000', '33.4', '25000', '9.62',
#        '22.5', '-9941.9', '17.1', '-260.33', '-2.08', '0.24', '260.33',
#        '2.08', '-49699.58', '-49363.67', '129.32', '301.76', '100000',
#        '-49697.54', '-49361.1', '-19517.7', '-24897.72', '1', '103.85',
#        '242.3', '-9938.52', '11.5', '-46.5', '46.5', '-6.33', '6.33',
#        '-4200', '60000', '-2000', '-4546.75', '-10000', '-730.8', '-1075',
#        '-750', '-136.46', '136.46', '-4596.2', '-2487.5', '-1100', '7.4',
#        '0.12', '-1.31', '0.06', '-2.94', '-94.14', '-7.41', '94.14',
#        '7.41', '16.7', '11.4', '-316.42', '-6.19', '316.42', '6.19',
#        '-98674.18', '-98672.92', '140000', '-100000', '-212.15', '212.15',
#        '-4.55', '4.55', '-9867.29', '-58434.8', '-59202.99', '148500',
#        '-29815.03', '-148500', '-19735.85', '-32.13', '32.13', '-2670',
#        '0.07', '-1.28', '0.15', '-2.97', '-64.78', '64.78', '1500',
#        '1000', '-19735.09', '0.74', '-0.24', '-114.19', '114.19', '0.00',
#        '16.8', '-9000', '6', '-9867.67', '10.5', '-91.55', '91.55',
#        '-1870', '0.16', '-1897.5', '-9867.92', '40000', '-9867.42',
#        '-9938.28', nan, '-276.66', '276.66', '-3.23', '0.17', '-99443.11',
#        '3.23', '165.38', '0.1', '136.71', '318.98', '-99442.33',
#        '-541.61', '541.61', '-2351.76', '2351.76', '-1164.25', '-12.87',
#        '1164.25', '12.87', '9.5', '-99721.56', '2395.56', '-19450.82',
#        '19450.82', '37.2', '4.2', '-107.93', '107.93', '27.3',
#        '-99438.44', '-99568.33', '18.6', '-167.4', '167.4', '200000',
#        '-99401.11', '-99697.44', '-49770.07', '10.57', '1.3', '1336.71',
#        '3118.98', '18.2', '8.2', '-99417.15', '34.5', '15', '-250.49',
#        '-1.15', '0.19', '250.49', '1.15', '-99394.89', '-99547.33',
#        '-99693.17', '-3800', '300000', '-99540.33', '-99384', '-11.89',
#        '-500.58', '11.89', '500.58', '12', '0.3', '-1.33', '0.52',
#        '-2.92', '14.23', '-245.69', '245.69', '-0.82', '0.82',
#        '-99377.78', '-199371.56', '-499', '5.88', '13.72', '250000',
#        '57.33', '-99366.67', '-99522.83', '-99362.22', '-201.98', '-2.91',
#        '201.98', '2.91', '-99343.56', '-99667.11', '-4630.9', '-3728.21',
#        '33.88', '14', '-111.12', '111.12', '-99332.67', '-11.79', '11.79',
#        '-99501.83', '-49464.74', '-99335.78', '-485.71', '-10.13',
#        '485.71', '10.13', '-99335', '-1570', '-980', '-1.3', '0.35',
#        '-2.95', '-491.39', '-10.19', '491.39', '10.19', '-49545.49',
#        '-99317.11', '-99484.33', '-99523.94', '-49462.85', '-99342.78',
#        '-550.06', '-9.29', '550.06', '9.29', '2032.74', '-99341.22',
#        '-99811.56', '-99494.15', '-336.77', '-7.85', '336.77', '7.85',
#        '-99506.5', '-49752.38', '-50000', '-70.35', '70.35', '110000',
#        '-283.42', '-9.22', '283.42', '9.22', '143.65', '335.2', '-1.23',
#        '-0.08', '-3.02', '13.55', '-441.08', '-6.83', '441.08', '6.83',
#        '-199013', '-49752.96', '-99671.39', '-99505.92', '24500', '25500',
#        '-186.16', '-5.07', '0.18', '186.16', '5.07', '-39802.6',
#        '-49303.35', '-1440', '-99504.17', '-473.06', '-4.48', '473.06',
#        '4.48', '-49834.72', '-98939.6', '-1180', '-49304.18', '-69255.95',
#        '-1.32', '0.4', '-2.93', '-46.64', '46.64', '-43.08', '0.13',
#        '43.08', '10.6', '5.2', '-2770', '-1500', '10', '-43.45', '43.45',
#        '-34.02', '34.02', '-32.21', '32.21', '0.05', '4.9', '-1645',
#        '-850', '-1200', '100', '29000', '-768.2', '-85.2', '-1481.45',
#        '-163.54', '-0.22', '-83.1', '83.1', '-9867.04', '-985', '-45.52',
#        '45.52', '-46.65', '46.65', '-50.75', '50.75', '-900', '-950',
#        '-53.84', '53.84', '-51.46', '51.46', '-49.16', '0.21', '49.16',
#        '-50.08', '50.08', '-45.79', '45.79', '-45.34', '45.34', '-47.25',
#        '47.25', '-930', '16.1', '-50.32', '50.32'], dtype=object)

# %%
transactions_df['Account'].unique()
# Out:
# array(['Individual', 'Cash Management (Individual)',
#        'Health Savings Account', nan], dtype=object)

# %%
transactions_df[transactions_df['Account']=='Health Savings Account'].head()
# Out:
#       Run Date                 Account Account Number  \
# 142 2024-01-17  Health Savings Account      241802439
# 156 2024-01-31  Health Savings Account      241802439
# 141 2024-02-01  Health Savings Account      241802439
# 140 2024-02-14  Health Savings Account      241802439
# 157 2024-02-26  Health Savings Account      241802439
#
#                                                 Action Symbol  \
# 142     PARTIC CONTR CURRENT PARTICIPANT CUR YR (Cash)
# 156  INTEREST EARNED FDIC INSURED DEPOSIT AT LEADER...  QKZCQ
# 141     PARTIC CONTR CURRENT PARTICIPANT CUR YR (Cash)
# 140     PARTIC CONTR CURRENT PARTICIPANT CUR YR (Cash)
# 157  EXCHANGED TO FDRXX FIDELITY GOVERNMENT CASH RE...  FDRXX
#
#                                  Description  Type  Quantity  Price ($)  \
# 142                           No Description  Cash       0.0        0.0
# 156  FDIC INSURED DEPOSIT AT LEADER BANK HSA  Cash       0.0        0.0
# 141                           No Description  Cash       0.0        0.0
# 140                           No Description  Cash       0.0        0.0
# 157        FIDELITY GOVERNMENT CASH RESERVES  Cash       0.0        0.0
#
#      Commission ($)  Fees ($)  Accrued Interest ($)  Amount ($)  \
# 142             0.0       0.0                   0.0      159.61
# 156             0.0       0.0                   0.0        0.16
# 141             0.0       0.0                   0.0      159.61
# 140             0.0       0.0                   0.0      159.61
# 157             0.0       0.0                   0.0        0.00
#
#     Settlement Date
# 142             NaT
# 156             NaT
# 141             NaT
# 140             NaT
# 157             NaT

# %% [markdown]
# ### load_data

# %%
from support_functions import analysis
importlib.reload(analysis)
from support_functions.data_loader import (
    get_latest_position_file, clean_positions,
    load_transactions, clean_transactions
)

# %%
data_dir = f'{project_path}/data'
pos_file, pos_date = get_latest_position_file(data_dir)
print(f"Loading positions from: {pos_file} (Date: {pos_date.strftime('%Y-%m-%d')})")
positions_df = pd.read_csv(pos_file, index_col=False)

positions_df = clean_positions(positions_df)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)

# %%
transactions_df = load_transactions(data_dir)
    
transactions_df = clean_transactions(transactions_df)
# Out:
# Found 4 history files.

# %%
# transactions_df[transactions_df['Symbol'] == 'AAPL']

# %% [markdown]
# ### Clean Data

# %%
from support_functions.data_loader import load_data

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
ref_df = positions_df[['Symbol', 'Description']].dropna().drop_duplicates()
desc_to_sym = dict(zip(ref_df['Description'].str.strip(), ref_df['Symbol'].str.strip()))

# %%
mask_missing_sym = transactions_df['Symbol'].isna() | (transactions_df['Symbol'] == '')
mapped_syms = transactions_df.loc[mask_missing_sym, 'Description'].str.strip().map(desc_to_sym)
transactions_df.loc[mask_missing_sym, 'Symbol'] = mapped_syms.fillna(transactions_df.loc[mask_missing_sym, 'Symbol'])

# %%
desc_to_sym['SP 500 INDEX PL CL F']
# Out:
# '84679P173'

# %%
transactions_df.loc[295]['Description']
SP 500 INDEX PL CL E
SP 500 INDEX PL CL F
# Out:
# 'SP 500 INDEX PL CL E'

# %%
transactions_df[transactions_df['Description']=='SP 500 INDEX PL CL E']
# Out:
#       Run Date               Account Account Number                  Action  \
# 295 2024-01-26  ERNST & YOUNG 401(K)          86964           Contributions
# 284 2024-02-09  ERNST & YOUNG 401(K)          86964           Contributions
# 277 2024-02-23  ERNST & YOUNG 401(K)          86964           Contributions
# 264 2024-03-08  ERNST & YOUNG 401(K)          86964           Contributions
# 260 2024-03-22  ERNST & YOUNG 401(K)          86964           Contributions
# ..         ...                   ...            ...                     ...
# 369 2025-11-14  ERNST & YOUNG 401(K)          86964           Contributions
# 360 2025-11-28  ERNST & YOUNG 401(K)          86964           Contributions
# 346 2025-12-12  ERNST & YOUNG 401(K)          86964           Contributions
# 336 2025-12-17  ERNST & YOUNG 401(K)          86964  Change In Market Value
# 337 2025-12-17  ERNST & YOUNG 401(K)          86964            Exchange Out
#
#     Symbol           Description Type  Price ($)  Quantity  Commission ($)  \
# 295    NaN  SP 500 INDEX PL CL E  NaN      1.070       0.0             0.0
# 284    NaN  SP 500 INDEX PL CL E  NaN      1.041       0.0             0.0
# 277    NaN  SP 500 INDEX PL CL E  NaN      1.027       0.0             0.0
# 264    NaN  SP 500 INDEX PL CL E  NaN      1.020       0.0             0.0
# 260    NaN  SP 500 INDEX PL CL E  NaN      0.997       0.0             0.0
# ..     ...                   ...  ...        ...       ...             ...
# 369    NaN  SP 500 INDEX PL CL E  NaN      9.770       0.0             0.0
# 360    NaN  SP 500 INDEX PL CL E  NaN      0.982       0.0             0.0
# 346    NaN  SP 500 INDEX PL CL E  NaN      0.985       0.0             0.0
# 336    NaN  SP 500 INDEX PL CL E  NaN      0.000       0.0             0.0
# 337    NaN  SP 500 INDEX PL CL E  NaN    -60.961       0.0             0.0
#
#      Fees ($)  Accrued Interest ($)  Amount ($) Settlement Date Asset Type
# 295       0.0                   0.0      242.30             NaT      Stock
# 284       0.0                   0.0      242.30             NaT      Stock
# 277       0.0                   0.0      242.30             NaT      Stock
# 264       0.0                   0.0      242.30             NaT      Stock
# 260       0.0                   0.0      242.30             NaT      Stock
# ..        ...                   ...         ...             ...        ...
# 369       0.0                   0.0     3118.98             NaT      Stock
# 360       0.0                   0.0      318.98             NaT      Stock
# 346       0.0                   0.0      318.98             NaT      Stock
# 336       0.0                   0.0     2395.56             NaT      Stock
# 337       0.0                   0.0   -19450.82             NaT      Stock
#
# [68 rows x 15 columns]

# %% [markdown]
# ## Business Logic Layer

# %% [markdown]
# ### filter_transactions

# %% [markdown]
# #### Z23390746 AAPL

# %% [markdown]
# #### ERNST & YOUNG 401(K) 86964

# %%
from support_functions.data_loader import load_data

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)

symbol = None
account_num = '86964'
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
df = transactions_df.copy()
funding_patterns = [
    'ELECTRONIC FUNDS TRANSFER', 'CHECK RECEIVED', 'DEPOSIT', 'WIRE', 
    'BILL PAY', 'CONTRIB', 'PARTIC CONTR'
]
mask_account = (df['Account Number'] == account_num)
mask_pattern = df['Action'].str.upper().apply(lambda x: any(p in str(x) for p in funding_patterns))

df = df[mask_account & mask_pattern]

# %%
transactions_df['Account Number'].unique()
# Out:
# array(['Z23390746', 'Z06872898', '241802439', '86964', nan], dtype=object)

# %%
account_num = '86964'
symbol = None
df = transactions_df.copy()
funding_patterns = [
    'ELECTRONIC FUNDS TRANSFER', 'CHECK RECEIVED', 'DEPOSIT', 'WIRE', 
    'BILL PAY', 'CONTRIB', 'PARTIC CONTR'
]
mask_account = (df['Account Number'] == account_num)
df = df[mask_account]

# %%
df
# Out:
#       Run Date               Account Account Number                  Action  \
# 294 2024-01-26  ERNST & YOUNG 401(K)          86964           Contributions
# 295 2024-01-26  ERNST & YOUNG 401(K)          86964           Contributions
# 284 2024-02-09  ERNST & YOUNG 401(K)          86964           Contributions
# 283 2024-02-09  ERNST & YOUNG 401(K)          86964           Contributions
# 277 2024-02-23  ERNST & YOUNG 401(K)          86964           Contributions
# ..         ...                   ...            ...                     ...
# 336 2025-12-17  ERNST & YOUNG 401(K)          86964  Change In Market Value
# 337 2025-12-17  ERNST & YOUNG 401(K)          86964            Exchange Out
# 334 2025-12-19  ERNST & YOUNG 401(K)          86964                Dividend
# 322 2025-12-26  ERNST & YOUNG 401(K)          86964           Contributions
# 323 2025-12-26  ERNST & YOUNG 401(K)          86964           Contributions
#
#     Symbol           Description Type  Price ($)  Quantity  Commission ($)  \
# 294    NaN   FID BLUE CHIP GR K6  NaN      3.716       0.0             0.0
# 295    NaN  SP 500 INDEX PL CL E  NaN      1.070       0.0             0.0
# 284    NaN  SP 500 INDEX PL CL E  NaN      1.041       0.0             0.0
# 283    NaN   FID BLUE CHIP GR K6  NaN      3.542       0.0             0.0
# 277    NaN  SP 500 INDEX PL CL E  NaN      1.027       0.0             0.0
# ..     ...                   ...  ...        ...       ...             ...
# 336    NaN  SP 500 INDEX PL CL E  NaN      0.000       0.0             0.0
# 337    NaN  SP 500 INDEX PL CL E  NaN    -60.961       0.0             0.0
# 334    NaN   FID BLUE CHIP GR K6  NaN      0.215       0.0             0.0
# 322    NaN   FID BLUE CHIP GR K6  NaN      3.047       0.0             0.0
# 323    NaN  SP 500 INDEX PL CL F  NaN      0.969       0.0             0.0
#
#      Fees ($)  Accrued Interest ($)  Amount ($) Settlement Date Asset Type
# 294       0.0                   0.0      103.85             NaT      Stock
# 295       0.0                   0.0      242.30             NaT      Stock
# 284       0.0                   0.0      242.30             NaT      Stock
# 283       0.0                   0.0      103.85             NaT      Stock
# 277       0.0                   0.0      242.30             NaT      Stock
# ..        ...                   ...         ...             ...        ...
# 336       0.0                   0.0     2395.56             NaT      Stock
# 337       0.0                   0.0   -19450.82             NaT      Stock
# 334       0.0                   0.0        9.50             NaT      Stock
# 322       0.0                   0.0      136.71             NaT      Stock
# 323       0.0                   0.0      318.98             NaT      Stock
#
# [141 rows x 15 columns]

# %%
account_num = '86964'
symbol = None
df = transactions_df.copy()
funding_patterns = [
    'ELECTRONIC FUNDS TRANSFER', 'CHECK RECEIVED', 'DEPOSIT', 'WIRE', 
    'BILL PAY', 'CONTRIB', 'PARTIC CONTR'
]
mask_account = (df['Account Number'] == account_num)
mask_pattern = df['Action'].str.upper().apply(lambda x: any(p in str(x) for p in funding_patterns))

df = df[mask_account & mask_pattern]
df['Amount ($)'].sum()
# Out:
# np.float64(24810.129999999997)

# %%
funding_patterns = ['ELECTRONIC FUNDS TRANSFER RECEIVED (CASH)']
df['Action'].str.upper().isin(funding_patterns)
# Out:
# 553     True
# 562    False
# 545    False
# 531    False
# 530    False
#        ...
# 255    False
# 252    False
# 247    False
# 246    False
# 250    False
# Name: Action, Length: 445, dtype: bool

# %% [markdown]
# ### filter_positions

# %%
from support_functions.data_loader import load_data
data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
symbol = 'AAPL'
df = positions_df.copy()
df = df[df['Symbol'] == symbol]
df.head(4)
# Out:
#    Account Number Account Name Symbol Description  Quantity  Last Price  \
# 10      Z23390746   Individual   AAPL   APPLE INC      70.0      271.86
#
#    Last Price Change  Current Value  Today's Gain/Loss Dollar  \
# 10            -$1.22        19030.2                     -85.4
#
#    Today's Gain/Loss Percent  Total Gain/Loss Dollar Total Gain/Loss Percent  \
# 10                    -0.45%                 8270.21                 +76.86%
#
#    Percent Of Account  Cost Basis Total Average Cost Basis  Type
# 10              1.52%          10759.99            $153.71  Cash

# %%
account_num = 'Z23390746'
df = positions_df.copy()
df = df[df['Account Number'] == account_num]
df.head(4)
# Out:
#   Account Number Account Name     Symbol  \
# 0      Z23390746   Individual  912797SG3
# 1      Z23390746   Individual      FXAIX
# 2      Z23390746   Individual    FZFXX**
# 3      Z23390746   Individual      FSKAX
#
#                                          Description    Quantity  Last Price  \
# 0  UNITED STATES TREAS BILLS ZERO CPN 0.00000% 01...  200000.000      99.823
# 1                            FIDELITY 500 INDEX FUND     749.338     237.720
# 2                               HELD IN MONEY MARKET       0.000       0.000
# 3                   FIDELITY TOTAL MARKET INDEX FUND     658.109     186.840
#
#   Last Price Change  Current Value  Today's Gain/Loss Dollar  \
# 0           +$0.018      199646.00                     36.00
# 1            -$1.74      178132.62                  -1303.85
# 2               NaN      128390.20                      0.00
# 3            -$1.42      122961.08                   -934.52
#
#   Today's Gain/Loss Percent  Total Gain/Loss Dollar Total Gain/Loss Percent  \
# 0                    +0.01%                  523.33                  +0.26%
# 1                    -0.73%                35568.68                 +24.94%
# 2                       NaN                    0.00                     NaN
# 3                    -0.76%                20661.19                 +20.19%
#
#   Percent Of Account  Cost Basis Total Average Cost Basis  Type
# 0             15.96%         199122.67                 --  Cash
# 1             14.24%         142563.94            $190.25  Cash
# 2             10.27%              0.00                NaN  Cash
# 3              9.83%         102299.89            $155.45  Cash

# %% [markdown]
# ### build_stock_cash_flows

# %% [markdown]
# #### Z23390746 AAPL

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions
)
data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
symbol = 'AAPL'
account_num = 'Z23390746'

# %%
filtered_hist = filter_transactions(transactions_df, account_num, symbol)
filtered_posi = filter_positions(positions_df, account_num, symbol)

# %%
cash_flows = []
total_invested = 0.0
current_val = filtered_posi['Current Value'].iloc[0]
for _, row in filtered_hist.iterrows():
    date = row['Run Date']
    amount = row['Amount ($)']
    flow = amount
    cash_flows.append((date, flow))
    
    # Track Invested Capital (Sum of negative flows)
    if flow < 0:
        total_invested += abs(flow)

cash_flows.append((latest_date, current_val))

# %%
cash_flows
# Out:
# [(Timestamp('2022-08-05 00:00:00'), -1481.45),
#  (Timestamp('2022-08-05 00:00:00'), -163.54),
#  (Timestamp('2022-08-26 00:00:00'), -1645.0),
#  (Timestamp('2022-08-29 00:00:00'), -3200.0),
#  (Timestamp('2022-11-01 00:00:00'), -1500.0),
#  (Timestamp('2022-11-08 00:00:00'), -2770.0),
#  (Timestamp('2022-11-10 00:00:00'), 11.5),
#  (Timestamp('2023-02-16 00:00:00'), 16.1),
#  (Timestamp('2023-05-18 00:00:00'), 16.8),
#  (Timestamp('2023-08-17 00:00:00'), 16.8),
#  (Timestamp('2023-11-16 00:00:00'), 16.8),
#  (Timestamp('2024-02-15 00:00:00'), 16.8),
#  (Timestamp('2024-05-16 00:00:00'), 17.5),
#  (Timestamp('2024-08-15 00:00:00'), 17.5),
#  (Timestamp('2024-11-14 00:00:00'), 17.5),
#  (Timestamp('2025-02-13 00:00:00'), 17.5),
#  (Timestamp('2025-05-15 00:00:00'), 18.2),
#  (Timestamp('2025-08-14 00:00:00'), 18.2),
#  (Timestamp('2025-11-13 00:00:00'), 18.2),
#  (Timestamp('2025-12-31 00:00:00'), np.float64(19030.2))]

# %% [markdown]
# #### 86964 FBCGX

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions
)
data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
symbol = 'FBCGX'
account_num = '86964'

# %%
filtered_hist = filter_transactions(transactions_df, account_num, symbol)
filtered_posi = filter_positions(positions_df, account_num, symbol)

# %%
filtered_hist
# Out:
# Empty DataFrame
# Columns: [Run Date, Account, Account Number, Action, Symbol, Description, Type, Price ($), Quantity, Commission ($), Fees ($), Accrued Interest ($), Amount ($), Settlement Date, Asset Type]
# Index: []

# %% [markdown]
# ### build_account_cash_flows

# %% [markdown]
# #### Individual Z23390746

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions
)
data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
symbol = None
account_num = 'Z23390746'

# %%
filtered_hist = filter_transactions(transactions_df, account_num, symbol)
filtered_posi = filter_positions(positions_df, account_num, symbol)
filtered_hist['Amount ($)'].sum()
# Out:
# np.float64(1100000.0)

# %%
cash_flows = []
total_invested = 0.0
current_val = filtered_posi['Current Value'].sum()
for _, row in filtered_hist.iterrows():
    date = row['Run Date']
    amount = row['Amount ($)']
    flow = -amount
    cash_flows.append((date, flow))
    
    # Track Invested Capital (Sum of negative flows)
    total_invested -= (flow)

cash_flows.append((latest_date, current_val))

# %%
total_invested
# Out:
# 1100000.0

# %% [markdown]
# #### ERNST & YOUNG 401(K) 86964

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions
)
data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)

symbol = None
account_num = '86964'
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
filtered_hist = filter_transactions(transactions_df, account_num, symbol)
filtered_posi = filter_positions(positions_df, account_num, symbol)
filtered_hist['Amount ($)'].sum()
# Out:
# np.float64(24810.129999999997)

# %% [markdown]
# ## Math Core Layer

# %% [markdown]
# ### xirr

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    build_stock_cash_flows, build_account_cash_flows
)
data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
symbol = None
account_num = 'Z23390746'

# %%
cash_flows, total_invested = build_account_cash_flows(transactions_df, positions_df, latest_date, account_num)

# %%
dates, amounts = width = zip(*cash_flows)
min_date = min(dates)
days = [(d - min_date).days for d in dates]

# Optimization function
def npv(r):
    arr = np.array(days)
    vals = np.array(amounts)
    return np.sum(vals / (1 + r)**(arr / 365.0))
    
# Check signs
pos = any(a > 0 for a in amounts)
neg = any(a < 0 for a in amounts)
res = optimize.newton(npv, 0.1, maxiter=50)
res
# Out:
# np.float64(0.09884212125959153)

# %% [markdown]
# ### calculate_metrics

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    build_stock_cash_flows, build_account_cash_flows,xirr
)
data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
symbol = 'AAPL'
account_num = 'Z23390746'

# %%
cash_flows, total_invested = build_account_cash_flows(transactions_df, positions_df, latest_date, account_num)

# %% [markdown]
# ## Analysis Level

# %% [markdown]
# ### analyze_entity_performance

# %% [markdown]
# #### AAPL

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions, 
    build_stock_cash_flows, build_account_cash_flows,
    xirr
)

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)

symbol = 'AAPL'
account_num = 'Z23390746'

cash_flows, total_invested = build_stock_cash_flows(transactions_df, positions_df, latest_date, account_num, symbol)
irr = xirr(cash_flows)
irr
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.
# np.float64(0.19542017278306092)

# %% [markdown]
# #### Individual Z23390746

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions, 
    build_stock_cash_flows, build_account_cash_flows,
    xirr
)

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)

symbol = None
account_num = 'Z23390746'

cash_flows, total_invested = build_account_cash_flows(transactions_df, positions_df, latest_date, account_num)
irr = xirr(cash_flows)
irr
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.
# np.float64(0.09884212125959153)

# %% [markdown]
# #### ERNST & YOUNG 401(K) 86964

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions, 
    build_stock_cash_flows, build_account_cash_flows,
    xirr
)

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)

symbol = 'FBCGX' # FBCGX 84679P173
account_num = '86964'
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
cash_flows, total_invested = build_stock_cash_flows(transactions_df, positions_df, latest_date, account_num, symbol)
irr = xirr(cash_flows)
irr

# %%
cash_flows
# Out:
# [(Timestamp('2025-12-31 00:00:00'), np.float64(9086.23))]

# %% [markdown]
# #### Cash Management (Individual) Z06872898

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions, 
    build_stock_cash_flows, build_account_cash_flows,
    xirr
)

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)

symbol = None
account_num = 'Z06872898'
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
cash_flows, total_invested = build_stock_cash_flows(transactions_df, positions_df, latest_date, account_num, symbol)

# %%
total_invested
# Out:
# 0.0

# %%
latest_date
# Out:
# Timestamp('2025-12-31 00:00:00')

# %% [markdown]
# ### analyze_account_performance

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions, 
    build_stock_cash_flows, build_account_cash_flows,
    xirr, analyze_entity_performance
)

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
accounts_unique = positions_df.groupby(['Account Number','Account Name'])['Current Value'].sum().reset_index()
accounts_unique
# Out:
#   Account Number                  Account Name  Current Value
# 0      241802439        Health Savings Account        9707.44
# 1          86964          ERNST & YOUNG 401(K)       29217.10
# 2      Z06872898  Cash Management (Individual)         108.17
# 3      Z23390746                    Individual     1250701.91

# %%
row = accounts_unique.iloc[0]
acc_num = row['Account Number']
acc_name = row['Account Name']
curr_val = row['Current Value']
acc_num
# Out:
# '241802439'

# %%
total_invested, irr = analyze_entity_performance(transactions_df, positions_df, latest_date, account_num=acc_num, symbol=None)
irr
# Out:
# np.float64(0.14987364529865643)

# %%
total_return = curr_val-total_invested
total_return_ratio = total_return/total_invested
{
    'Account Name': acc_name,
    'Account Number': acc_num,
    'Symbol': None,
    'Asset Type': 'Account',
    'Current Value': curr_val,
    'Total Invested': total_invested,
    'Total Return ($)': total_return,
    'Total Return (%)': total_return_ratio,
    'IRR': irr
}
# Out:
# {'Account Name': 'Health Savings Account',
#  'Account Number': '241802439',
#  'Symbol': None,
#  'Asset Type': 'Account',
#  'Current Value': np.float64(9707.439999999999),
#  'Total Invested': 8450.640000000003,
#  'Total Return ($)': np.float64(1256.7999999999956),
#  'Total Return (%)': np.float64(0.1487224636240563),
#  'IRR': np.float64(0.14987364529865643)}

# %%
total_invested
# Out:
# 8.170000000000005

# %%
results = []
    
accounts_unique = positions_df.groupby(['Account Number','Account Name'])['Current Value'].sum().reset_index()

for _, row in accounts_unique.iterrows():
    acc_num = row['Account Number']
    acc_name = row['Account Name']
    curr_val = row['Current Value']
    if acc_name == 'ERNST & YOUNG 401(K)':
        continue
    
    total_invested, irr = analyze_entity_performance(transactions_df, positions_df, latest_date, account_num=acc_num, symbol=None)
    total_return = curr_val-total_invested
    total_return_ratio = total_return/total_invested
    
    results.append({
        'Account Name': acc_name,
        'Account Number': acc_num,
        'Symbol': None,
        'Asset Type': 'Account',
        'Current Value': curr_val,
        'Total Invested': total_invested,
        'Total Return ($)': total_return,
        'Total Return (%)': total_return_ratio,
        'IRR': irr
    })
pd.DataFrame(results)
# Out:
#                    Account Name Account Number Symbol Asset Type  \
# 0        Health Savings Account      241802439   None    Account
# 1  Cash Management (Individual)      Z06872898   None    Account
# 2                    Individual      Z23390746   None    Account
#
#    Current Value  Total Invested  Total Return ($)  Total Return (%)       IRR
# 0        9707.44         8450.64           1256.80          0.148722  0.149874
# 1         108.17            8.17            100.00         12.239902  2.463594
# 2     1250701.91      1100000.00         150701.91          0.137002  0.098842

# %% [markdown]
# ### analyze_stock_performance

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions, 
    build_stock_cash_flows, build_account_cash_flows,
    xirr, analyze_entity_performance
)

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
results = []

accounts_unique = positions_df.groupby(['Account Number','Account Name'])['Current Value'].sum().reset_index()
accounts_unique
# Out:
#   Account Number                  Account Name  Current Value
# 0      241802439        Health Savings Account        9707.44
# 1          86964          ERNST & YOUNG 401(K)       29217.10
# 2      Z06872898  Cash Management (Individual)         108.17
# 3      Z23390746                    Individual     1250701.91

# %%
row = accounts_unique.iloc[1]
acc_num = row['Account Number']
acc_name = row['Account Name']

# %%
sub_positions_df = positions_df[
    (positions_df['Account Name'] == acc_name) &
    (positions_df['Asset Type'] == 'Stock')
]
sub_positions_df
# Out:
#    Account Number          Account Name     Symbol           Description  \
# 30          86964  ERNST & YOUNG 401(K)  84679P173  SP 500 INDEX PL CL F
# 31          86964  ERNST & YOUNG 401(K)      FBCGX   FID BLUE CHIP GR K6
#
#     Quantity  Last Price Last Price Change  Current Value  \
# 30    61.924      325.09            -$2.38       20130.87
# 31   205.385       44.24            -$0.32        9086.23
#
#     Today's Gain/Loss Dollar Today's Gain/Loss Percent  \
# 30                   -147.38                    -0.73%
# 31                    -65.73                    -0.72%
#
#     Total Gain/Loss Dollar Total Gain/Loss Percent Percent Of Account  \
# 30                  361.07                  +1.83%             68.90%
# 31                 1558.84                 +20.71%             31.10%
#
#     Cost Basis Total Average Cost Basis Type Asset Type
# 30          19769.80            $319.26  NaN      Stock
# 31           7527.39             $36.65  NaN      Stock

# %%
sub_row = sub_positions_df.iloc[1]
sub_row
# Out:
# Account Number                              86964
# Account Name                 ERNST & YOUNG 401(K)
# Symbol                                      FBCGX
# Description                   FID BLUE CHIP GR K6
# Quantity                                  205.385
# Last Price                                  44.24
# Last Price Change                          -$0.32
# Current Value                             9086.23
# Today's Gain/Loss Dollar                   -65.73
# Today's Gain/Loss Percent                  -0.72%
# Total Gain/Loss Dollar                    1558.84
# Total Gain/Loss Percent                   +20.71%
# Percent Of Account                         31.10%
# Cost Basis Total                          7527.39
# Average Cost Basis                         $36.65
# Type                                          NaN
# Asset Type                                  Stock
# Name: 31, dtype: object

# %%
sub_positions_df = positions_df[
    (positions_df['Account Name'] == acc_name) &
    (positions_df['Asset Type'] == 'Stock')
]
sub_row = sub_positions_df.iloc[1]
symbol = sub_row['Symbol']
curr_val = sub_row['Current Value']


total_invested, irr = analyze_entity_performance(transactions_df, positions_df, latest_date, account_num=acc_num, symbol=symbol)
{
    'Account Name': acc_name,
    'Account Number': acc_num,
    'Symbol': symbol,
    'Asset Type': 'Stock',
    'Current Value': curr_val,
    'Total Invested': total_invested,
    'Total Return ($)': total_return,
    'Total Return (%)': total_return_ratio,
    'IRR': irr
}
# Out:
# {'Account Name': 'ERNST & YOUNG 401(K)',
#  'Account Number': '86964',
#  'Symbol': 'FBCGX',
#  'Asset Type': 'Stock',
#  'Current Value': np.float64(9086.23),
#  'Total Invested': 0.0,
#  'Total Return ($)': np.float64(4406.970000000005),
#  'Total Return (%)': np.float64(0.1776278479798375),
#  'IRR': None}

# %%
results = []

accounts_unique = positions_df.groupby(['Account Number','Account Name'])['Current Value'].sum().reset_index()

for _, row in accounts_unique.iterrows():

    acc_num = row['Account Number']
    acc_name = row['Account Name']


    target_type = 'Stock'
    sub_positions_df = positions_df[
        (positions_df['Account Name'] == acc_name) &
        (positions_df['Asset Type'] == target_type)
    ]

    for _, sub_row in sub_positions_df.iterrows():
        symbol = sub_row['Symbol']
        curr_val = sub_row['Current Value']
        if symbol in ['Pending activity']:
            continue

        total_invested, irr = analyze_entity_performance(transactions_df, positions_df, latest_date, account_num=acc_num, symbol=symbol)
        results.append({
            'Account Name': acc_name,
            'Account Number': acc_num,
            'Symbol': symbol,
            'Asset Type': 'Stock',
            'Current Value': curr_val,
            'Total Invested': total_invested,
            'Total Return ($)': total_return,
            'Total Return (%)': total_return_ratio,
            'IRR': irr
        })
pd.DataFrame(results)
# Out:
#                     Account Name Account Number     Symbol Asset Type  \
# 0         Health Savings Account      241802439      FXAIX      Stock
# 1         Health Savings Account      241802439      FZILX      Stock
# 2           ERNST & YOUNG 401(K)          86964  84679P173      Stock
# 3           ERNST & YOUNG 401(K)          86964      FBCGX      Stock
# 4   Cash Management (Individual)      Z06872898     CORE**      Stock
# 5                     Individual      Z23390746      FXAIX      Stock
# 6                     Individual      Z23390746      FSKAX      Stock
# 7                     Individual      Z23390746      FSPSX      Stock
# 8                     Individual      Z23390746       AAPL      Stock
# 9                     Individual      Z23390746       MSFT      Stock
# 10                    Individual      Z23390746       BRKB      Stock
# 11                    Individual      Z23390746       TSLA      Stock
# 12                    Individual      Z23390746      GOOGL      Stock
# 13                    Individual      Z23390746        MCD      Stock
# 14                    Individual      Z23390746        GLD      Stock
# 15                    Individual      Z23390746        AXP      Stock
# 16                    Individual      Z23390746        JPM      Stock
# 17                    Individual      Z23390746       COKE      Stock
# 18                    Individual      Z23390746       SBUX      Stock
# 19                    Individual      Z23390746        KHC      Stock
# 20                    Individual      Z23390746       AMZN      Stock
# 21                    Individual      Z23390746         VZ      Stock
# 22                    Individual      Z23390746        NKE      Stock
# 23                    Individual      Z23390746       NVDA      Stock
# 24                    Individual      Z23390746        PEP      Stock
# 25                    Individual      Z23390746         PG      Stock
# 26                    Individual      Z23390746       COST      Stock
#
#     Current Value  Total Invested  Total Return ($)  Total Return (%)  \
# 0         4232.36         3560.87           4406.97          0.177628
# 1         4144.74         3836.14           4406.97          0.177628
# 2        20130.87            0.00           4406.97          0.177628
# 3         9086.23            0.00           4406.97          0.177628
# 4          108.17            0.00           4406.97          0.177628
# 5       178132.62       142563.94           4406.97          0.177628
# 6       122961.08       102299.89           4406.97          0.177628
# 7        76959.48        63994.40           4406.97          0.177628
# 8        19030.20        10759.99           4406.97          0.177628
# 9        14508.60        13342.95           4406.97          0.177628
# 10       10053.00         9230.90           4406.97          0.177628
# 11        8994.40         3767.50           4406.97          0.177628
# 12        6260.00         1830.00           4406.97          0.177628
# 13        6112.60         5157.50           4406.97          0.177628
# 14        3963.10         3800.00           4406.97          0.177628
# 15        3691.30         1500.00           4406.97          0.177628
# 16        3222.20         1200.00           4406.97          0.177628
# 17        3066.00         2175.00           4406.97          0.177628
# 18        2526.30         2453.40           4406.97          0.177628
# 19        2425.00         3200.00           4406.97          0.177628
# 20        2308.20          950.00           4406.97          0.177628
# 21        2036.50         2100.00           4406.97          0.177628
# 22        1911.30         2580.80           4406.97          0.177628
# 23        1865.00         1180.00           4406.97          0.177628
# 24        1435.20         1440.00           4406.97          0.177628
# 25        1433.10         1570.00           4406.97          0.177628
# 26         862.34          980.00           4406.97          0.177628
#
#          IRR
# 0   0.167011
# 1   0.300799
# 2        NaN
# 3        NaN
# 4        NaN
# 5   0.222154
# 6   0.167138
# 7   0.177839
# 8   0.195420
# 9   0.066716
# 10  0.111919
# 11  0.571119
# 12  0.541373
# 13  0.138307
# 14  0.248957
# 15  0.324517
# 16  0.371657
# 17  1.021591
# 18  0.038295
# 19 -0.165863
# 20  0.363938
# 21  0.034058
# 22 -0.121120
# 23  0.639832
# 24  0.029642
# 25 -0.148653
# 26 -0.229633

# %% [markdown]
# ### analyze_total_performance

# %%
from support_functions.data_loader import load_data
from support_functions.analysis import (
    filter_transactions, filter_positions, 
    build_stock_cash_flows, build_account_cash_flows,
    xirr, analyze_entity_performance
)

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)



accounts_unique = positions_df.groupby(['Account Number','Account Name'])['Current Value'].sum().reset_index()
accounts_unique
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.
#   Account Number                  Account Name  Current Value
# 0      241802439        Health Savings Account        9707.44
# 1          86964          ERNST & YOUNG 401(K)       29217.10
# 2      Z06872898  Cash Management (Individual)         108.17
# 3      Z23390746                    Individual     1250701.91

# %%
total_cash_flows = []
total_invested = 0
total_val = 0
for _, row in accounts_unique.iterrows():
    acc_num = row['Account Number']
    curr_val = row['Current Value']
    cash_flows, curr_invested = build_account_cash_flows(transactions_df, positions_df, latest_date, acc_num)
    total_val += curr_val
    total_invested += curr_invested
    total_cash_flows.extend(cash_flows)
irr = xirr(total_cash_flows)
irr
# Out:
# np.float64(0.10063390508140015)

# %%
total_return = total_val-total_invested
total_return_ratio = total_return/total_invested
result = [{
    'Account Name': None,
    'Account Number': None,
    'Symbol': None,
    'Asset Type': 'All',
    'Current Value': total_val,
    'Total Invested': total_invested,
    'Total Return ($)': total_return,
    'Total Return (%)': f"{total_return_ratio:.2%}",
    'IRR': f"{irr:.2%}" if irr is not None else "N/A"
}]
pd.DataFrame(result)
# Out:
#   Account Name Account Number Symbol Asset Type  Current Value  \
# 0         None           None   None        All     1289734.62
#
#    Total Invested  Total Return ($) Total Return (%)     IRR
# 0      1133360.77         156373.85           13.80%  10.06%

# %% [markdown]
# ## LLM Level

# %%
from support_functions.data_loader import (
    load_data
)
from support_functions.analysis import (
    analyze_account_performance,
    analyze_stock_performance,
    analyze_total_performance
)
from support_functions.report_generator import generate_markdown_report

# %%
data_dir = f'{project_path}/data'
output_dir = f'{project_path}/output'
data = load_data(data_dir)

print("\n" + "="*50)
print("FIDELITY PORTFOLIO ANALYSIS")
print("="*50)

# 1. Total Portfolio Performance
print("Calculating metrics...")
total_res = analyze_total_performance(data)

# 2. Calculate performance for all positions
account_res = analyze_account_performance(data)

# 3. Stock Level
stock_res = analyze_stock_performance(data)

# Generate Report
output_dir = project_path / 'output'
output_dir.mkdir(exist_ok=True)
report_str = generate_markdown_report(total_res, account_res, stock_res, data.latest_date, output_dir=str(output_dir))
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.
#
# ==================================================
# FIDELITY PORTFOLIO ANALYSIS
# ==================================================
# Calculating metrics...
# Report saved to: /Users/yifanli/Github/fidelity-portfolio-tracker/output/Portfolio_Report_2025-12-31.md

# %%
report_str
# Out:
# '# Fidelity Portfolio Analysis Report\n**Date:** 2025-12-31\n\n## 1. Total Portfolio Performance\n| Account Name   | Account Number   | Symbol   | Asset Type   |   Current Value |   Total Invested |   Total Return ($) | Total Return (%)   | IRR    | Investment Ratio   |   Holding Period (Y) |\n|:---------------|:-----------------|:---------|:-------------|----------------:|-----------------:|-------------------:|:-------------------|:-------|:-------------------|---------------------:|\n|                |                  |          | All          |      1289734.62 |       1133360.77 |          156373.85 | 13.80%             | 10.06% | 100%               |                 1.42 |\n\n\n## 2. Performance by Account\n| Account Name                 | Account Number   | Symbol   | Asset Type   |   Current Value |   Total Invested |   Total Return ($) | Total Return (%)   | IRR    |   Holding Period (Y) | Investment Ratio   |\n|:-----------------------------|:-----------------|:---------|:-------------|----------------:|-----------------:|-------------------:|:-------------------|:-------|---------------------:|:-------------------|\n| Individual                   | Z23390746        |          | Account      |      1250701.91 |       1100000.00 |          150701.91 | 13.70%             | 9.88%  |                 1.43 | 97.06%             |\n| ERNST & YOUNG 401(K)         | 86964            |          | Account      |        29217.10 |         24810.13 |            4406.97 | 17.76%             | 22.02% |                 0.79 | 2.19%              |\n| Health Savings Account       | 241802439        |          | Account      |         9707.44 |          8450.64 |            1256.80 | 14.87%             | 14.99% |                 0.97 | 0.75%              |\n| Cash Management (Individual) | Z06872898        |          | Account      |          108.17 |           100.00 |               8.17 | 8.17%              | 2.31%  |                 3.44 | 0.01%              |\n\n\n## 3. Performance by Stocks\n| Account Name   | Account Number   | Symbol   | Asset Type   |   Current Value |   Total Invested |   Total Return ($) | Total Return (%)   | IRR     |   Holding Period (Y) | Investment Ratio   |\n|:---------------|:-----------------|:---------|:-------------|----------------:|-----------------:|-------------------:|:-------------------|:--------|---------------------:|:-------------------|\n| Individual     | Z23390746        | FXAIX    | Stock        |       178132.62 |        142563.94 |           35568.68 | 24.95%             | 22.22%  |                 1.17 | 37.71%             |\n| Individual     | Z23390746        | FSKAX    | Stock        |       122961.08 |        102299.89 |           20661.19 | 20.20%             | 16.71%  |                 1.31 | 27.06%             |\n| Individual     | Z23390746        | FSPSX    | Stock        |        76959.48 |         63994.40 |           12965.08 | 20.26%             | 17.78%  |                 1.45 | 16.93%             |\n| Individual     | Z23390746        | MSFT     | Stock        |        14508.60 |         13342.95 |            1165.65 | 8.74%              | 6.67%   |                 1.46 | 3.53%              |\n| Individual     | Z23390746        | AAPL     | Stock        |        19030.20 |         10759.99 |            8270.21 | 76.86%             | 19.54%  |                 3.28 | 2.85%              |\n| Individual     | Z23390746        | BRKB     | Stock        |        10053.00 |          9230.90 |             822.10 | 8.91%              | 11.19%  |                 0.80 | 2.44%              |\n| Individual     | Z23390746        | MCD      | Stock        |         6112.60 |          5157.50 |             955.10 | 18.52%             | 13.83%  |                 1.62 | 1.36%              |\n| Individual     | Z23390746        | GLD      | Stock        |         3963.10 |          3800.00 |             163.10 | 4.29%              | 24.90%  |                 0.19 | 1.01%              | ...

# %%
import os
from google import genai
from google.genai import types


api_key = os.getenv("GEMINI_API_KEY")
model="gemini-3-flash-preview"

grounding_tool = types.Tool(
    google_search=types.GoogleSearch()
)

# %%
system_prompt = "你是一个资深体育分析师"
user_prompt = "告诉我最新的欧冠排名"

# %%
client = genai.Client(api_key=api_key)
config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(thinking_budget=0), # Disables thinking
    temperature=1,
    system_instruction = system_prompt,
    tools=[grounding_tool]
)

response = client.models.generate_content(
    model=model,
    contents=prompt,
    config=config,
)
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[19], line 8
#       1 client = genai.Client(api_key=api_key)
#       2 config=types.GenerateContentConfig(
#       3     thinking_config=types.ThinkingConfig(thinking_budget=0), # Disables thinking
#       4     temperature=1,
#       5     system_instruction = system_prompt
#       6 )
# ----> 8 response = client.models.generate_content(
#       9     model=model,
#      10     contents=prompt,
#      11     config=config,
#      12 )
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/google/genai/models.py:5215, in Models.generate_content(self, model, contents, config)
#    5213 while remaining_remote_calls_afc > 0:
#    5214   i += 1
# -> 5215   response = self._generate_content(
#    5216       model=model, contents=contents, config=parsed_config
#    5217   )
#    5219   function_map = _extra_utils.get_function_map(parsed_config)
#    5220   if not function_map:
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/google/genai/models.py:3997, in Models._generate_content(self, model, contents, config)
#    3994 request_dict = _common.convert_to_dict(request_dict)
#    3995 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3997 response = self._api_client.request(
#    3998     'post', path, request_dict, http_options
#    3999 )
#    4001 if config is not None and getattr(
#    4002     config, 'should_return_http_response', None
#    4003 ):
#    4004   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1375, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1365 def request(
#    1366     self,
#    1367     http_method: str,
#    (...)   1370     http_options: Optional[HttpOptionsOrDict] = None,
#    1371 ) -> SdkHttpResponse:
#    1372   http_request = self._build_request(
#    1373       http_method, path, request_dict, http_options
#    1374   )
# -> 1375   response = self._request(http_request, http_options, stream=False)
#    1376   response_body = (
#    1377       response.response_stream[0] if response.response_stream else ''
#    1378   )
#    1379   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1211, in BaseApiClient._request(self, http_request, http_options, stream)
#    1208     retry = tenacity.Retrying(**retry_kwargs)
#    1209     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1211 return self._retry(self._request_once, http_request, stream)
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1188, in BaseApiClient._request_once(self, http_request, stream)
#    1180 else:
#    1181   response = self._httpx_client.request(
#    1182       method=http_request.method,
#    1183       url=http_request.url,
#    (...)   1186       timeout=http_request.timeout,
#    1187   )
# -> 1188   errors.APIError.raise_for_response(response)
#    1189   return HttpResponse(
#    1190       response.headers, response if stream else [response.text]
#    1191   )
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/google/genai/errors.py:121, in APIError.raise_for_response(cls, response)
#     118 else:
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/google/genai/errors.py:148, in APIError.raise_error(cls, status_code, response_json, response)
#     146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
# --> 148   raise ServerError(status_code, response_json, response)
#     149 else:
#     150   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
response.text
# Out:
# '喵！我是Neko！很高兴认识你！\n\n我是一只非常可爱的猫咪，有着柔软的皮毛和一双闪闪发光的眼睛。我最喜欢的事情就是晒太阳，躺在温暖的窗台上打盹，或者追着我的玩具老鼠跑来跑去。\n\n我有点害羞，但如果你轻轻地抚摸我的下巴，我会发出咕噜咕噜的声音，表示我很喜欢你。我喜欢被抓挠耳朵，如果你能给我挠挠，我会非常高兴的！\n\n我喜欢吃鱼，尤其是小鱼干，那是我最爱的零食！\n\n你有什么想问我的吗？我很乐意和你聊聊，喵！'

# %%
response.total_token_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 response.total_token_count
#
# File ~/Github/fidelity-portfolio-tracker/.venv/lib/python3.12/site-packages/pydantic/main.py:1026, in BaseModel.__getattr__(self, item)
#    1023     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1024 else:
#    1025     # this is the current error
# -> 1026     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'GenerateContentResponse' object has no attribute 'total_token_count'
