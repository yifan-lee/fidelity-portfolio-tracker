# %% [markdown]
# ## Start

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pathlib import Path
import os
import glob
from scipy import optimize
import importlib

# %%
project_path = Path.cwd().parent
data_dir = f'{project_path}/data'
output_dir = f'{project_path}/output'

# %%
test_case_pair = [
    ("Z23390746", "AAPL"),
    ("Z23390746", "FXAIX"),
    ("Z23390746", "912797SZ1"),
    ("Z23390746", "912797RJ8"),
    ("86964", "84679P173"),
    ("86964", "FBCGX"),
    ("Z06872898", None),
    ("241802439", "FZILX"),
    ("241802439", "FXAIX"),
]

# %% [markdown]
# # data_loader

# %% [markdown]
# ## get_latest_position_file

# %%
files = glob.glob(os.path.join(data_dir, 'Portfolio_Positions_*.csv'))
files
# Out:
# ['/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Apr-06-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Aug-05-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Nov-16-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Apr-29-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-15-2026.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Apr-02-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_May-06-2025.csv',
#  '/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv']

# %%
latest_file = None
latest_date = None

for f in files:
    basename = os.path.basename(f)
    date_part = basename.replace('Portfolio_Positions_', '').replace('.csv', '')
    try:
        date_obj = datetime.strptime(date_part, '%b-%d-%Y')
        if latest_date is None or date_obj > latest_date:
            latest_date = date_obj
            latest_file = f
    except ValueError:
        continue
latest_date = pd.to_datetime(latest_date)
[latest_file, latest_date]
# Out:
# ['/Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv',
#  Timestamp('2026-01-31 00:00:00')]

# %% [markdown]
# ## clean_positions

# %%
from support_functions.data_loader import get_latest_position_file, clean_currency

data_dir = f'{project_path}/data'
pos_file, pos_date = get_latest_position_file(data_dir)
positions_df = pd.read_csv(pos_file, index_col=False)
positions_df = positions_df.dropna(subset=['Account Name'])
cols_to_clean = [
    'Last Price', 'Current Value', 
    'Cost Basis Total', 'Today\'s Gain/Loss Dollar', 
    'Total Gain/Loss Dollar'
]

# %%
for col in cols_to_clean:
    if col in positions_df.columns:
        positions_df[col] = positions_df[col].apply(clean_currency)

# Clean Quantity (remove match for formatting issues if any)
if 'Quantity' in positions_df.columns:
    positions_df['Quantity'] = pd.to_numeric(positions_df['Quantity'], errors='coerce').fillna(0)

# %%
positions_df['Account Name'].unique()
# Out:
# array(['Individual', 'ERNST & YOUNG 401(K)',
#        'Cash Management (Individual)', 'Health Savings Account'],
#       dtype=object)

# %% [markdown]
# ## load_transactions

# %%
data_dir = f'{project_path}/data'
max_cols=14
hist_files = glob.glob(os.path.join(data_dir, 'Accounts_History_*.csv'))
transactions_dfs = []
print(f"Found {len(hist_files)} history files.")

for f in hist_files:
    df = pd.read_csv(f, header=0, usecols=range(max_cols))
    transactions_dfs.append(df)

transactions_df = pd.concat(transactions_dfs, ignore_index=True)
# Out:
# Found 4 history files.

# %%
transactions_df.columns
# Out:
# Index(['Run Date', 'Account', 'Account Number', 'Action', 'Symbol',
#        'Description', 'Type', 'Price ($)', 'Quantity', 'Commission ($)',
#        'Fees ($)', 'Accrued Interest ($)', 'Amount ($)', 'Settlement Date'],
#       dtype='object')

# %%
transactions_df['Account'].unique()
# Out:
# array(['Individual', 'Health Savings Account',
#        'Cash Management (Individual)', 'ERNST & YOUNG 401(K)', nan],
#       dtype=object)

# %%
[transactions_df.iloc[292]['Run Date'],transactions_df.iloc[228]['Run Date']]
# Out:
# ['01/31/2024', '04/25/2024']

# %% [markdown]
# ## clean_transactions

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_transactions, clean_currency
data_dir = f'{project_path}/data'
transactions_df = load_transactions(data_dir)
# Out:
# Found 5 history files.

# %%
transactions_df.columns
# Out:
# Index(['Run Date', 'Account', 'Account Number', 'Action', 'Symbol',
#        'Description', 'Type', 'Price ($)', 'Quantity', 'Commission ($)',
#        'Fees ($)', 'Accrued Interest ($)', 'Amount ($)', 'Settlement Date'],
#       dtype='object')

# %%
transactions_df['Account'].unique()
# Out:
# array(['Individual', 'Health Savings Account',
#        'Cash Management (Individual)', 'ERNST & YOUNG 401(K)', nan],
#       dtype=object)

# %%
transactions_df[transactions_df['Action'].str.contains('Exchange',na=False)]
# Out:
#        Run Date               Account Account Number        Action Symbol  \
# 337  12/17/2025  ERNST & YOUNG 401(K)          86964  Exchange Out    NaN
# 338  12/17/2025  ERNST & YOUNG 401(K)          86964   Exchange In    NaN
#
#               Description Type  Price ($)  Quantity  Commission ($)  Fees ($)  \
# 337  SP 500 INDEX PL CL E  NaN    -60.961       NaN             NaN       NaN
# 338  SP 500 INDEX PL CL F  NaN     60.955       NaN             NaN       NaN
#
#      Accrued Interest ($)  Amount ($) Settlement Date
# 337                   NaN   -19450.82             NaN
# 338                   NaN    19450.82             NaN

# %%
transactions_df['Amount ($)'].unique()
# Out:
# array(['Amount ($)', '-198.36', '-3.26', '0.2', '198.36', '3.26',
#        '159.61', '40', '132.4', '308.95', '30000', '-342.04', '342.04',
#        '-1642.64', '1642.64', '-11.12', '-1065.29', '11.12', '1065.29',
#        '4.85', '35.4', '4', '-98925.69', '-2100', '24.9', '20000',
#        '-20000', '-40000', '150000', '-99486.67', '18.3', '-120.16',
#        '120.16', '-2.05', '50000', '2.05', '17.5', '-19861.24', '-3200',
#        '-29840.57', '5', '7', '105.92', '247.16', '12.5', '-211.35',
#        '211.35', '-1.7', '0.22', '1.7', '-19891.97', '-49432.51', '70000',
#        '-4600', '-49429.35', '-19926.11', '-49424.93', '-6.64', '-241.99',
#        '6.64', '241.99', '-1000', '5.33', '12.44', '11.1', '0.08',
#        '-1.27', '0.28', '-2.98', '-83.8', '83.8', '-3.44', '0.23',
#        '-29658.75', '3.44', '-29838.3', '10000', '33.4', '25000', '9.62',
#        '22.5', '-9941.9', '17.1', '-260.33', '-2.08', '0.24', '260.33',
#        '2.08', '-49699.58', '-49363.67', '129.32', '301.76', '100000',
#        '-49697.54', '-49361.1', '-19517.7', '-24897.72', '1', '103.85',
#        '242.3', '-9938.52', '11.5', '-46.5', '46.5', '-6.33', '6.33',
#        '-4200', '60000', '-2000', '-4546.75', '-10000', '-730.8', '-1075',
#        '-750', '-136.46', '136.46', '-4596.2', '-2487.5', '-1100', '7.4',
#        '0.12', '-1.31', '0.06', '-2.94', '-94.14', '-7.41', '94.14',
#        '7.41', '16.7', '11.4', '-316.42', '-6.19', '316.42', '6.19',
#        '-98674.18', '-98672.92', '140000', '-100000', '-212.15', '212.15',
#        '-4.55', '4.55', '-9867.29', '-58434.8', '-59202.99', '148500',
#        '-29815.03', '-148500', '-19735.85', '-32.13', '32.13', '-2670',
#        '0.07', '-1.28', '0.15', '-2.97', '-64.78', '64.78', '1500',
#        '1000', '-19735.09', '0.74', '-0.24', '-114.19', '114.19', '0.00',
#        '16.8', '-9000', '6', '-9867.67', '10.5', '-91.55', '91.55',
#        '-1870', '0.16', '-1897.5', '-9867.92', '40000', '-9867.42',
#        '-9938.28', nan, '-276.66', '276.66', '-3.23', '0.17', '-99443.11',
#        '3.23', '165.38', '0.1', '136.71', '318.98', '-99442.33',
#        '-541.61', '541.61', '-2351.76', '2351.76', '-1164.25', '-12.87',
#        '1164.25', '12.87', '9.5', '-99721.56', '2395.56', '-19450.82',
#        '19450.82', '37.2', '4.2', '-107.93', '107.93', '27.3',
#        '-99438.44', '-99568.33', '18.6', '-167.4', '167.4', '200000',
#        '-99401.11', '-99697.44', '-49770.07', '10.57', '1.3', '1336.71',
#        '3118.98', '18.2', '8.2', '-99417.15', '34.5', '15', '-250.49',
#        '-1.15', '0.19', '250.49', '1.15', '-99394.89', '-99547.33',
#        '-99693.17', '-3800', '300000', '-99540.33', '-99384', '-11.89',
#        '-500.58', '11.89', '500.58', '12', '0.3', '-1.33', '0.52',
#        '-2.92', '14.23', '-245.69', '245.69', '-0.82', '0.82',
#        '-99377.78', '-199371.56', '-499', '5.88', '13.72', '250000',
#        '57.33', '-99366.67', '-99522.83', '-99362.22', '-201.98', '-2.91',
#        '201.98', '2.91', '-99343.56', '-99667.11', '-4630.9', '-3728.21',
#        '33.88', '14', '-111.12', '111.12', '-99332.67', '-11.79', '11.79',
#        '-99501.83', '-49464.74', '-99335.78', '-485.71', '-10.13',
#        '485.71', '10.13', '-99335', '-1570', '-980', '-1.3', '0.35',
#        '-2.95', '-491.39', '-10.19', '491.39', '10.19', '-49545.49',
#        '-99317.11', '-99484.33', '-99523.94', '-49462.85', '-99342.78',
#        '-550.06', '-9.29', '550.06', '9.29', '2032.74', '-99341.22',
#        '-99811.56', '-99494.15', '-336.77', '-7.85', '336.77', '7.85',
#        '-99506.5', '-49752.38', '-50000', '-70.35', '70.35', '110000',
#        '-283.42', '-9.22', '283.42', '9.22', '143.65', '335.2', '-1.23',
#        '-0.08', '-3.02', '13.55', '-441.08', '-6.83', '441.08', '6.83',
#        '-199013', '-49752.96', '-99671.39', '-99505.92', '24500', '25500',
#        '-186.16', '-5.07', '0.18', '186.16', '5.07', '-39802.6',
#        '-49303.35', '-1440', '-99504.17', '-473.06', '-4.48', '473.06',
#        '4.48', '-49834.72', '-98939.6', '-1180', '-49304.18', '-69255.95',
#        '-1.32', '0.4', '-2.93', '-46.64', '46.64', '-43.08', '0.13',
#        '43.08', '10.6', '5.2', '-2770', '-1500', '10', '-43.45', '43.45',
#        '-34.02', '34.02', '-32.21', '32.21', '0.05', '4.9', '-1645',
#        '-850', '-1200', '100', '29000', '-768.2', '-85.2', '-1481.45',
#        '-163.54', '-0.22', '-83.1', '83.1', '-9867.04', '-985', '-45.52',
#        '45.52', '-46.65', '46.65', '-50.75', '50.75', '-900', '-950',
#        '-53.84', '53.84', '-51.46', '51.46', '-49.16', '0.21', '49.16',
#        '-50.08', '50.08', '-45.79', '45.79', '-45.34', '45.34', '-47.25',
#        '47.25', '-930', '16.1', '-50.32', '50.32'], dtype=object)

# %%
transactions_df['Account'].unique()
# Out:
# array(['Individual', 'Cash Management (Individual)',
#        'Health Savings Account', nan], dtype=object)

# %%
transactions_df[transactions_df['Account']=='Health Savings Account'].head()
# Out:
#       Run Date                 Account Account Number  \
# 142 2024-01-17  Health Savings Account      241802439
# 156 2024-01-31  Health Savings Account      241802439
# 141 2024-02-01  Health Savings Account      241802439
# 140 2024-02-14  Health Savings Account      241802439
# 157 2024-02-26  Health Savings Account      241802439
#
#                                                 Action Symbol  \
# 142     PARTIC CONTR CURRENT PARTICIPANT CUR YR (Cash)
# 156  INTEREST EARNED FDIC INSURED DEPOSIT AT LEADER...  QKZCQ
# 141     PARTIC CONTR CURRENT PARTICIPANT CUR YR (Cash)
# 140     PARTIC CONTR CURRENT PARTICIPANT CUR YR (Cash)
# 157  EXCHANGED TO FDRXX FIDELITY GOVERNMENT CASH RE...  FDRXX
#
#                                  Description  Type  Quantity  Price ($)  \
# 142                           No Description  Cash       0.0        0.0
# 156  FDIC INSURED DEPOSIT AT LEADER BANK HSA  Cash       0.0        0.0
# 141                           No Description  Cash       0.0        0.0
# 140                           No Description  Cash       0.0        0.0
# 157        FIDELITY GOVERNMENT CASH RESERVES  Cash       0.0        0.0
#
#      Commission ($)  Fees ($)  Accrued Interest ($)  Amount ($)  \
# 142             0.0       0.0                   0.0      159.61
# 156             0.0       0.0                   0.0        0.16
# 141             0.0       0.0                   0.0      159.61
# 140             0.0       0.0                   0.0      159.61
# 157             0.0       0.0                   0.0        0.00
#
#     Settlement Date
# 142             NaT
# 156             NaT
# 141             NaT
# 140             NaT
# 157             NaT

# %% [markdown]
# ## load_data

# %%
from support_functions import analysis
importlib.reload(analysis)
from support_functions.data_loader import (
    get_latest_position_file, clean_positions,
    load_transactions, clean_transactions
)

# %%
data_dir = f'{project_path}/data'
pos_file, pos_date = get_latest_position_file(data_dir)
print(f"Loading positions from: {pos_file} (Date: {pos_date.strftime('%Y-%m-%d')})")
positions_df = pd.read_csv(pos_file, index_col=False)

positions_df = clean_positions(positions_df)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)

# %%
transactions_df = load_transactions(data_dir)
    
transactions_df = clean_transactions(transactions_df)
# Out:
# Found 4 history files.

# %%
# transactions_df[transactions_df['Symbol'] == 'AAPL']

# %% [markdown]
# ## Clean Data

# %%
from support_functions.data_loader import load_data

data_dir = f'{project_path}/data'
positions_df, transactions_df, latest_date = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Dec-31-2025.csv (Date: 2025-12-31)
# Found 4 history files.

# %%
ref_df = positions_df[['Symbol', 'Description']].dropna().drop_duplicates()
desc_to_sym = dict(zip(ref_df['Description'].str.strip(), ref_df['Symbol'].str.strip()))

# %%
mask_missing_sym = transactions_df['Symbol'].isna() | (transactions_df['Symbol'] == '')
mapped_syms = transactions_df.loc[mask_missing_sym, 'Description'].str.strip().map(desc_to_sym)
transactions_df.loc[mask_missing_sym, 'Symbol'] = mapped_syms.fillna(transactions_df.loc[mask_missing_sym, 'Symbol'])

# %%
desc_to_sym['SP 500 INDEX PL CL F']
# Out:
# '84679P173'

# %%
transactions_df.loc[295]['Description']
SP 500 INDEX PL CL E
SP 500 INDEX PL CL F
# Out:
# 'SP 500 INDEX PL CL E'

# %%
transactions_df[transactions_df['Description']=='SP 500 INDEX PL CL E']
# Out:
#       Run Date               Account Account Number                  Action  \
# 295 2024-01-26  ERNST & YOUNG 401(K)          86964           Contributions
# 284 2024-02-09  ERNST & YOUNG 401(K)          86964           Contributions
# 277 2024-02-23  ERNST & YOUNG 401(K)          86964           Contributions
# 264 2024-03-08  ERNST & YOUNG 401(K)          86964           Contributions
# 260 2024-03-22  ERNST & YOUNG 401(K)          86964           Contributions
# ..         ...                   ...            ...                     ...
# 369 2025-11-14  ERNST & YOUNG 401(K)          86964           Contributions
# 360 2025-11-28  ERNST & YOUNG 401(K)          86964           Contributions
# 346 2025-12-12  ERNST & YOUNG 401(K)          86964           Contributions
# 336 2025-12-17  ERNST & YOUNG 401(K)          86964  Change In Market Value
# 337 2025-12-17  ERNST & YOUNG 401(K)          86964            Exchange Out
#
#     Symbol           Description Type  Price ($)  Quantity  Commission ($)  \
# 295    NaN  SP 500 INDEX PL CL E  NaN      1.070       0.0             0.0
# 284    NaN  SP 500 INDEX PL CL E  NaN      1.041       0.0             0.0
# 277    NaN  SP 500 INDEX PL CL E  NaN      1.027       0.0             0.0
# 264    NaN  SP 500 INDEX PL CL E  NaN      1.020       0.0             0.0
# 260    NaN  SP 500 INDEX PL CL E  NaN      0.997       0.0             0.0
# ..     ...                   ...  ...        ...       ...             ...
# 369    NaN  SP 500 INDEX PL CL E  NaN      9.770       0.0             0.0
# 360    NaN  SP 500 INDEX PL CL E  NaN      0.982       0.0             0.0
# 346    NaN  SP 500 INDEX PL CL E  NaN      0.985       0.0             0.0
# 336    NaN  SP 500 INDEX PL CL E  NaN      0.000       0.0             0.0
# 337    NaN  SP 500 INDEX PL CL E  NaN    -60.961       0.0             0.0
#
#      Fees ($)  Accrued Interest ($)  Amount ($) Settlement Date Asset Type
# 295       0.0                   0.0      242.30             NaT      Stock
# 284       0.0                   0.0      242.30             NaT      Stock
# 277       0.0                   0.0      242.30             NaT      Stock
# 264       0.0                   0.0      242.30             NaT      Stock
# 260       0.0                   0.0      242.30             NaT      Stock
# ..        ...                   ...         ...             ...        ...
# 369       0.0                   0.0     3118.98             NaT      Stock
# 360       0.0                   0.0      318.98             NaT      Stock
# 346       0.0                   0.0      318.98             NaT      Stock
# 336       0.0                   0.0     2395.56             NaT      Stock
# 337       0.0                   0.0   -19450.82             NaT      Stock
#
# [68 rows x 15 columns]

# %% [markdown]
# # flow_builder

# %% [markdown]
# ## filter_entity_transactions

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_data

# %%
data = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
account_num, entity_name = test_case_pair[6]

transactions_df = data.transactions
transactions_df.head()
# Out:
#       Run Date     Account Account Number  \
# 747 2022-07-26  Individual      Z23390746
# 746 2022-07-29  Individual      Z23390746
# 745 2022-07-29  Individual      Z23390746
# 744 2022-08-05  Individual      Z23390746
# 743 2022-08-05  Individual      Z23390746
#
#                                                 Action Symbol  \
# 747          Electronic Funds Transfer Received (Cash)
# 746  DIVIDEND RECEIVED FIDELITY TREASURY MONEY MARK...  FZFXX
# 745  REINVESTMENT FIDELITY TREASURY MONEY MARKET FU...  FZFXX
# 744                 YOU BOUGHT APPLE INC (AAPL) (Cash)   AAPL
# 743                 YOU BOUGHT APPLE INC (AAPL) (Cash)   AAPL
#
#                              Description  Type  Price ($)  Quantity  \
# 747                       No Description  Cash       0.00      0.00
# 746  FIDELITY TREASURY MONEY MARKET FUND  Cash       0.00      0.00
# 745  FIDELITY TREASURY MONEY MARKET FUND  Cash       1.00      0.22
# 744                            APPLE INC  Cash     163.54      1.00
# 743                            APPLE INC  Cash     164.61      9.00
#
#      Commission ($)  Fees ($)  Accrued Interest ($)  Amount ($)  \
# 747             0.0       0.0                   0.0    -1000.00
# 746             0.0       0.0                   0.0        0.22
# 745             0.0       0.0                   0.0       -0.22
# 744             0.0       0.0                   0.0     -163.54
# 743             0.0       0.0                   0.0    -1481.45
#
#     Settlement Date Asset Type
# 747             NaT   Transfer
# 746             NaT       Cash
# 745             NaT       Cash
# 744      2022-08-09      Stock
# 743      2022-08-09      Stock

# %%
data.transactions[data.transactions['Account Number']=='Z06872898']
# Out:
#       Run Date                       Account Account Number  \
# 739 2022-08-16  Cash Management (Individual)      Z06872898
# 733 2022-08-31  Cash Management (Individual)      Z06872898
# 728 2022-09-30  Cash Management (Individual)      Z06872898
# 725 2022-10-31  Cash Management (Individual)      Z06872898
# 716 2022-11-30  Cash Management (Individual)      Z06872898
# 713 2022-12-30  Cash Management (Individual)      Z06872898
# 815 2023-01-31  Cash Management (Individual)      Z06872898
# 805 2023-02-28  Cash Management (Individual)      Z06872898
# 802 2023-03-31  Cash Management (Individual)      Z06872898
# 799 2023-04-28  Cash Management (Individual)      Z06872898
# 792 2023-05-31  Cash Management (Individual)      Z06872898
# 789 2023-06-30  Cash Management (Individual)      Z06872898
# 786 2023-07-31  Cash Management (Individual)      Z06872898
# 779 2023-08-31  Cash Management (Individual)      Z06872898
# 774 2023-09-29  Cash Management (Individual)      Z06872898
# 771 2023-10-31  Cash Management (Individual)      Z06872898
# 764 2023-11-30  Cash Management (Individual)      Z06872898
# 758 2023-12-29  Cash Management (Individual)      Z06872898
# 291 2024-01-31  Cash Management (Individual)      Z06872898
# 270 2024-02-29  Cash Management (Individual)      Z06872898
# 253 2024-03-28  Cash Management (Individual)      Z06872898
# 223 2024-04-30  Cash Management (Individual)      Z06872898
# 197 2024-05-31  Cash Management (Individual)      Z06872898
# 174 2024-06-28  Cash Management (Individual)      Z06872898
# 142 2024-07-31  Cash Management (Individual)      Z06872898
# 115 2024-08-30  Cash Management (Individual)      Z06872898
# 93  2024-09-30  Cash Management (Individual)      Z06872898
# 61  2024-10-31  Cash Management (Individual)      Z06872898
# 37  2024-11-29  Cash Management (Individual)      Z06872898
# 2   2024-12-31  Cash Management (Individual)      Z06872898
# 633 2025-01-31  Cash Management (Individual)      Z06872898
# 611 2025-02-28  Cash Management (Individual)      Z06872898
# 585 2025-03-31  Cash Management (Individual)      Z06872898
# 554 2025-04-30  Cash Management (Individual)      Z06872898
# 527 2025-05-30  Cash Management (Individual)      Z06872898
# 502 2025-06-30  Cash Management (Individual)      Z06872898
# 471 2025-07-31  Cash Management (Individual)      Z06872898
# 443 2025-08-29  Cash Management (Individual)      Z06872898
# 416 2025-09-30  Cash Management (Individual)      Z06872898
# 381 2025-10-31  Cash Management (Individual)      Z06872898
# 356 2025-11-28  Cash Management (Individual)      Z06872898
# 315 2025-12-31  Cash Management (Individual)      Z06872898
# 674 2026-01-30  Cash Management (Individual)      Z06872898
#
#                                                 Action Symbol  \
# 739                                   JOURNALED (Cash)    NaN
# 733  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 728  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 725  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 716  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 713  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 815  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 805  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 802  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 799  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 792  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 789  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 786  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 779  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 774  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 771  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 764  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 758  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 291  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 270  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 253  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 223  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 197  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 174  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 142  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 115  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 93   INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 61   INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 37   INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 2    INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 633  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 611  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 585  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 554  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 527  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 502  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 471  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 443  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 416  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 381  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 356  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 315  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
# 674  INTEREST EARNED FDIC INSURED DEPOSIT AT US BAN...  QUSBQ
#
#                                  Description  Type  Price ($)  Quantity  \
# 739                           No Description  Cash        0.0       0.0
# 733  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 728  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 725  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 716  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 713  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 815  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 805  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 802  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 799  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 792  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 789  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 786  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 779  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 774  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 771  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 764  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 758  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 291  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 270  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 253  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 223  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 197  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 174  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 142  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 115  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 93   FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 61   FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 37   FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 2    FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 633  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 611  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 585  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 554  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 527  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 502  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 471  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 443  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 416  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 381  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 356  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 315  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
# 674  FDIC INSURED DEPOSIT AT US BANK NOT COV  Cash        0.0       0.0
#
#      Commission ($)  Fees ($)  Accrued Interest ($)  Amount ($)  \
# 739             0.0       0.0                   0.0      100.00
# 733             0.0       0.0                   0.0        0.05
# 728             0.0       0.0                   0.0        0.10
# 725             0.0       0.0                   0.0        0.13
# 716             0.0       0.0                   0.0        0.13
# 713             0.0       0.0                   0.0        0.17
# 815             0.0       0.0                   0.0        0.19
# 805             0.0       0.0                   0.0        0.18
# 802             0.0       0.0                   0.0        0.20
# 799             0.0       0.0                   0.0        0.20
# 792             0.0       0.0                   0.0        0.22
# 789             0.0       0.0                   0.0        0.21
# 786             0.0       0.0                   0.0        0.22
# 779             0.0       0.0                   0.0        0.23
# 774             0.0       0.0                   0.0        0.23
# 771             0.0       0.0                   0.0        0.23
# 764             0.0       0.0                   0.0        0.23
# 758             0.0       0.0                   0.0        0.24
# 291             0.0       0.0                   0.0        0.24
# 270             0.0       0.0                   0.0        0.22
# 253             0.0       0.0                   0.0        0.24
# 223             0.0       0.0                   0.0        0.23
# 197             0.0       0.0                   0.0        0.24
# 174             0.0       0.0                   0.0        0.23
# 142             0.0       0.0                   0.0        0.24
# 115             0.0       0.0                   0.0        0.24
# 93              0.0       0.0                   0.0        0.23
# 61              0.0       0.0                   0.0        0.22
# 37              0.0       0.0                   0.0        0.20
# 2               0.0       0.0                   0.0        0.20
# 633             0.0       0.0                   0.0        0.20
# 611             0.0       0.0                   0.0        0.18
# 585             0.0       0.0                   0.0        0.20
# 554             0.0       0.0                   0.0        0.19
# 527             0.0       0.0                   0.0        0.20
# 502             0.0       0.0                   0.0        0.19
# 471             0.0       0.0                   0.0        0.20
# 443             0.0       0.0                   0.0        0.20
# 416             0.0       0.0                   0.0        0.19
# 381             0.0       0.0                   0.0        0.19
# 356             0.0       0.0                   0.0        0.17
# 315             0.0       0.0                   0.0        0.17
# 674             0.0       0.0                   0.0        0.17
#
#     Settlement Date Asset Type
# 739             NaT      Stock
# 733             NaT       Cash
# 728             NaT       Cash
# 725             NaT       Cash
# 716             NaT       Cash
# 713             NaT       Cash
# 815             NaT       Cash
# 805             NaT       Cash
# 802             NaT       Cash
# 799             NaT       Cash
# 792             NaT       Cash
# 789             NaT       Cash
# 786             NaT       Cash
# 779             NaT       Cash
# 774             NaT       Cash
# 771             NaT       Cash
# 764             NaT       Cash
# 758             NaT       Cash
# 291             NaT       Cash
# 270             NaT       Cash
# 253             NaT       Cash
# 223             NaT       Cash
# 197             NaT       Cash
# 174             NaT       Cash
# 142             NaT       Cash
# 115             NaT       Cash
# 93              NaT       Cash
# 61              NaT       Cash
# 37              NaT       Cash
# 2               NaT       Cash
# 633             NaT       Cash
# 611             NaT       Cash
# 585             NaT       Cash
# 554             NaT       Cash
# 527             NaT       Cash
# 502             NaT       Cash
# 471             NaT       Cash
# 443             NaT       Cash
# 416             NaT       Cash
# 381             NaT       Cash
# 356             NaT       Cash
# 315             NaT       Cash
# 674             NaT       Cash

# %% [markdown]
# ## filter_entity_positions

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_data

# %%
data = load_data(data_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
account_num, entity_name = test_case_pair[0]

positions_df = data.positions
positions_df.head()
# Out:
#   Account Number Account Name     Symbol  \
# 0      Z23390746   Individual      FXAIX
# 1      Z23390746   Individual      FSKAX
# 2      Z23390746   Individual  912797SQ1
# 3      Z23390746   Individual  912797SR9
# 4      Z23390746   Individual  912797SS7
#
#                                          Description    Quantity  Last Price  \
# 0                            FIDELITY 500 INDEX FUND     749.338     241.160
# 1                   FIDELITY TOTAL MARKET INDEX FUND     658.109     189.750
# 2  UNITED STATES TREAS BILLS ZERO CPN 0.00000% 02...  100000.000      99.921
# 3  UNITED STATES TREAS BILLS ZERO CPN 0.00000% 02...  100000.000      99.849
# 4  UNITED STATES TREAS BILLS ZERO CPN 0.00000% 02...  100000.000      99.779
#
#   Last Price Change  Current Value  Today's Gain/Loss Dollar  \
# 0            -$1.03      180710.35                   -771.82
# 1            -$1.07      124876.18                   -704.18
# 2           +$0.032       99921.00                     32.00
# 3           +$0.031       99849.00                     31.00
# 4           +$0.031       99779.00                     31.00
#
#   Today's Gain/Loss Percent  Total Gain/Loss Dollar Total Gain/Loss Percent  \
# 0                    -0.43%                38146.41                 +26.75%
# 1                    -0.57%                22576.29                 +22.06%
# 2                    +0.03%                  482.56                  +0.48%
# 3                    +0.03%                  128.61                  +0.12%
# 4                    +0.03%                  336.67                  +0.33%
#
#   Percent Of Account  Cost Basis Total Average Cost Basis  Type Asset Type
# 0             14.34%         142563.94            $190.25  Cash      Stock
# 1              9.91%         102299.89            $155.45  Cash      Stock
# 2              7.93%          99438.44                 --  Cash       Bond
# 3              7.92%          99720.39                 --  Cash       Bond
# 4              7.92%          99442.33                 --  Cash       Bond

# %% [markdown]
# ## build_entity_cash_flows

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_data

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    filter_entity_transactions,
    filter_entity_positions,
    EntityCashFlows
)

data = load_data(data_dir)
transactions_df = data.transactions
positions_df = data.positions
latest_date = data.latest_date
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
account_num, entity_name = test_case_pair[4]

filtered_hist = filter_entity_transactions(transactions_df, account_num, entity_name)
filtered_posi = filter_entity_positions(positions_df, account_num, entity_name)
[account_num, entity_name]
# Out:
# ['86964', '84679P173']

# %%
cash_flows = []
total_invested = 0.0    
current_val = filtered_posi['Current Value'].iloc[0] if not filtered_posi.empty else 0.0
current_basis = filtered_posi['Cost Basis Total'].iloc[0] if not filtered_posi.empty else 0.0

# %%
for _, row in filtered_hist.iterrows():
    date = row['Run Date']
    amount = row['Amount ($)']
    flow = amount
    cash_flows.append((date, flow))
    
    if flow < 0:
        total_invested += abs(flow)

# %%
[total_invested,current_basis, current_val]
# Out:
# [39879.45000000001, np.float64(20404.91), np.float64(21056.77)]

# %%
cash_flows
# Out:
# [(Timestamp('2024-07-22 00:00:00'), -2000.0),
#  (Timestamp('2024-10-04 00:00:00'), 6.64),
#  (Timestamp('2024-10-04 00:00:00'), -6.64),
#  (Timestamp('2024-10-04 00:00:00'), -1000.0),
#  (Timestamp('2024-12-20 00:00:00'), -11.12),
#  (Timestamp('2024-12-20 00:00:00'), 11.12),
#  (Timestamp('2025-04-04 00:00:00'), 9.22),
#  (Timestamp('2025-04-04 00:00:00'), -9.22),
#  (Timestamp('2025-07-11 00:00:00'), -10.13),
#  (Timestamp('2025-07-11 00:00:00'), 10.13),
#  (Timestamp('2025-09-18 00:00:00'), -499.0),
#  (Timestamp('2025-10-03 00:00:00'), 11.89),
#  (Timestamp('2025-10-03 00:00:00'), -11.89),
#  (Timestamp('2025-12-19 00:00:00'), 12.87),
#  (Timestamp('2025-12-19 00:00:00'), -12.87)]

# %%
positions_df[positions_df['Account Number']==account_num]
# Out:
#    Account Number            Account Name   Symbol  \
# 34      241802439  Health Savings Account    FZILX
# 35      241802439  Health Savings Account    FXAIX
# 36      241802439  Health Savings Account  FDRXX**
#
#                           Description  Quantity  Last Price Last Price Change  \
# 34  FIDELITY ZERO INTERNATIONAL INDEX   281.381       15.59            -$0.24
# 35            FIDELITY 500 INDEX FUND    17.804      241.16            -$1.03
# 36               HELD IN MONEY MARKET     0.000        0.00               NaN
#
#     Current Value  Today's Gain/Loss Dollar Today's Gain/Loss Percent  \
# 34        4386.72                    -67.54                    -1.52%
# 35        4293.61                    -18.34                    -0.43%
# 36        1673.02                      0.00                       NaN
#
#     Total Gain/Loss Dollar Total Gain/Loss Percent Percent Of Account  \
# 34                  550.58                 +14.35%             42.37%
# 35                  732.74                 +20.57%             41.47%
# 36                    0.00                     NaN             16.16%
#
#     Cost Basis Total Average Cost Basis  Type Asset Type
# 34           3836.14             $13.63  Cash      Stock
# 35           3560.87            $200.00  Cash      Stock
# 36              0.00                NaN  Cash       Cash

# %%
transactions_df[transactions_df['Account Number']==account_num]['Description'].unique()
# Out:
# array(['No Description', 'FDIC INSURED DEPOSIT AT LEADER BANK HSA',
#        'FIDELITY GOVERNMENT CASH RESERVES', 'FIDELITY 500 INDEX FUND',
#        'FIDELITY ZERO INTERNATIONAL INDEX'], dtype=object)

# %%
transactions_df[
    (transactions_df['Account Number']==account_num) &
    (transactions_df['Description']=='FIDELITY ZERO INTERNATIONAL INDEX')
]
# Out:
#       Run Date                 Account Account Number  \
# 462 2025-08-06  Health Savings Account      241802439
# 344 2025-12-12  Health Savings Account      241802439
# 343 2025-12-12  Health Savings Account      241802439
#
#                                                 Action Symbol  \
# 462  YOU BOUGHT PROSPECTUS UNDER SEPARATE COVER FID...  FZILX
# 344  DIVIDEND RECEIVED FIDELITY ZERO INTERNATIONAL ...  FZILX
# 343  REINVESTMENT FIDELITY ZERO INTERNATIONAL INDEX...  FZILX
#
#                            Description  Type  Price ($)  Quantity  \
# 462  FIDELITY ZERO INTERNATIONAL INDEX  Cash      13.61   273.932
# 344  FIDELITY ZERO INTERNATIONAL INDEX  Cash       0.00     0.000
# 343  FIDELITY ZERO INTERNATIONAL INDEX  Cash      14.49     7.449
#
#      Commission ($)  Fees ($)  Accrued Interest ($)  Amount ($)  \
# 462             0.0       0.0                   0.0    -3728.21
# 344             0.0       0.0                   0.0      107.93
# 343             0.0       0.0                   0.0     -107.93
#
#     Settlement Date Asset Type
# 462      2025-08-07      Stock
# 344             NaT      Stock
# 343             NaT      Stock

# %% [markdown]
# ## build_asset_class_cash_flows

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_data

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    filter_entity_transactions,
    filter_entity_positions,
    EntityCashFlows
)

data = load_data(data_dir)
transactions_df = data.transactions
positions_df = data.positions
latest_date = data.latest_date
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
asset_class = 'Stock'
account_num, entity_name = test_case_pair[0]


transactions_df = data.transactions
positions_df = data.positions
latest_date = data.latest_date

filtered_hist = transactions_df[
    (transactions_df['Account Number'] == account_num) &
    (transactions_df['Asset Type'] == asset_class)
]
filtered_posi = positions_df[
    (positions_df['Account Number'] == account_num) &
    (positions_df['Asset Type'] == asset_class)
]

cash_flows = []
total_invested = 0.0
current_val = filtered_posi['Current Value'].sum()
current_basis = filtered_posi['Cost Basis Total'].sum()
for _, row in filtered_hist.iterrows():
    date = row['Run Date']
    amount = row['Amount ($)']
    flow = amount
    cash_flows.append((date, flow))
    
    if flow < 0:
        total_invested += abs(flow)

# %%
[total_invested, current_basis, current_val]
# Out:
# [399361.26999999996, np.float64(399361.26999999996), np.float64(502149.93)]

# %%
# filtered_hist.to_csv("/Users/yifanli/Github/fidelity-portfolio-tracker/data/temp.csv")

# %% [markdown]
# ## build_account_cash_flows

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_data

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    filter_account_transactions,
    filter_account_positions,
    EntityCashFlows
)

data = load_data(data_dir)
transactions_df = data.transactions
positions_df = data.positions
latest_date = data.latest_date
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
account_num, entity_name = test_case_pair[6]


transactions_df = data.transactions
positions_df = data.positions
latest_date = data.latest_date

filtered_hist = filter_account_transactions(transactions_df, account_num)
filtered_posi = filter_account_positions(positions_df, account_num)


cash_flows = []
total_invested = 0.0
current_val = filtered_posi['Current Value'].sum()
current_basis = filtered_posi['Cost Basis Total'].sum()
for _, row in filtered_hist.iterrows():
    date = row['Run Date']
    amount = row['Amount ($)']
    flow = amount
    cash_flows.append((date, flow))
    
total_invested = sum([flow for _, flow in cash_flows])

cash_flows.append((latest_date, current_val))
result = EntityCashFlows(
    cash_flows=cash_flows, 
    total_invested=total_invested, 
    current_value=current_val,
    latest_date=latest_date
)

# %%
cash_flows
# Out:
# [(Timestamp('2022-08-16 00:00:00'), -100.0),
#  (Timestamp('2022-08-31 00:00:00'), 0.05),
#  (Timestamp('2022-09-30 00:00:00'), 0.1),
#  (Timestamp('2022-10-31 00:00:00'), 0.13),
#  (Timestamp('2022-11-30 00:00:00'), 0.13),
#  (Timestamp('2022-12-30 00:00:00'), 0.17),
#  (Timestamp('2023-01-31 00:00:00'), 0.19),
#  (Timestamp('2023-02-28 00:00:00'), 0.18),
#  (Timestamp('2023-03-31 00:00:00'), 0.2),
#  (Timestamp('2023-04-28 00:00:00'), 0.2),
#  (Timestamp('2023-05-31 00:00:00'), 0.22),
#  (Timestamp('2023-06-30 00:00:00'), 0.21),
#  (Timestamp('2023-07-31 00:00:00'), 0.22),
#  (Timestamp('2023-08-31 00:00:00'), 0.23),
#  (Timestamp('2023-09-29 00:00:00'), 0.23),
#  (Timestamp('2023-10-31 00:00:00'), 0.23),
#  (Timestamp('2023-11-30 00:00:00'), 0.23),
#  (Timestamp('2023-12-29 00:00:00'), 0.24),
#  (Timestamp('2024-01-31 00:00:00'), 0.24),
#  (Timestamp('2024-02-29 00:00:00'), 0.22),
#  (Timestamp('2024-03-28 00:00:00'), 0.24),
#  (Timestamp('2024-04-30 00:00:00'), 0.23),
#  (Timestamp('2024-05-31 00:00:00'), 0.24),
#  (Timestamp('2024-06-28 00:00:00'), 0.23),
#  (Timestamp('2024-07-31 00:00:00'), 0.24),
#  (Timestamp('2024-08-30 00:00:00'), 0.24),
#  (Timestamp('2024-09-30 00:00:00'), 0.23),
#  (Timestamp('2024-10-31 00:00:00'), 0.22),
#  (Timestamp('2024-11-29 00:00:00'), 0.2),
#  (Timestamp('2024-12-31 00:00:00'), 0.2),
#  (Timestamp('2025-01-31 00:00:00'), 0.2),
#  (Timestamp('2025-02-28 00:00:00'), 0.18),
#  (Timestamp('2025-03-31 00:00:00'), 0.2),
#  (Timestamp('2025-04-30 00:00:00'), 0.19),
#  (Timestamp('2025-05-30 00:00:00'), 0.2),
#  (Timestamp('2025-06-30 00:00:00'), 0.19),
#  (Timestamp('2025-07-31 00:00:00'), 0.2),
#  (Timestamp('2025-08-29 00:00:00'), 0.2),
#  (Timestamp('2025-09-30 00:00:00'), 0.19),
#  (Timestamp('2025-10-31 00:00:00'), 0.19),
#  (Timestamp('2025-11-28 00:00:00'), 0.17),
#  (Timestamp('2025-12-31 00:00:00'), 0.17),
#  (Timestamp('2026-01-30 00:00:00'), 0.17),
#  (Timestamp('2026-01-31 00:00:00'), np.float64(108.34))]

# %%
xirr(cash_flows)
# Out:
# np.float64(0.1702665577099441)

# %% [markdown]
# # math_utils

# %% [markdown]
# ## get_total_pnl

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_data

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    build_entity_cash_flows,
    build_account_cash_flows
)

# %%
data = load_data(data_dir)
transactions_df = data.transactions
positions_df = data.positions
latest_date = data.latest_date
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
account_num, entity_name = test_case_pair[0]

# entity_cash_flows = build_entity_cash_flows(data, account_num, entity_name)
entity_cash_flows = build_account_cash_flows(data, account_num)

# %%
cash_flows = entity_cash_flows.cash_flows
total_invested = entity_cash_flows.total_invested
current_value = entity_cash_flows.current_value
current_basis = entity_cash_flows.current_basis
latest_date = entity_cash_flows.latest_date

[total_invested, current_basis, current_value]
# Out:
# [1100000.0, np.float64(1095876.6199999999), np.float64(1260161.97)]

# %%
total_invested
# Out:
# 1100000.0

# %%
total_pnl = sum(amount for date, amount in cash_flows)
total_pnl
# Out:
# np.float64(160161.96999999997)

# %%
entity_cash_flows.total_invested
# Out:
# -1100000.0

# %%
[total_invested,current_basis,current_value]
# Out:
# [39879.45000000001, np.float64(20404.91), np.float64(21056.77)]

# %%
def xirr(cash_flows):
    """
    Calculate Internal Rate of Return (XIRR).
    cash_flows: List of (date, amount) tuples.
    """
    if not cash_flows or len(cash_flows) < 2:
        return None
        
    dates, amounts = zip(*cash_flows)
    
    # Convert dates to days from start
    min_date = min(dates)
    days = [(d - min_date).days for d in dates]
    
    # Optimization function
    def npv(r):
        arr = np.array(days)
        vals = np.array(amounts)
        return np.sum(vals / (1 + r)**(arr / 365.0))
        
    # Check signs
    pos = any(a > 0 for a in amounts)
    neg = any(a < 0 for a in amounts)
    if not (pos and neg):
        return None # Can't calculate IRR without both inflows and outflows
        
    try:
        res = optimize.newton(npv, 0.1, maxiter=50) # start guess at 10%
        return res
    except RuntimeError:
        return None


irr_val = xirr(cash_flows)
irr_val
# Out:
# np.float64(0.09848867226958016)

# %% [markdown]
# ## get_macaulay_duration

# %%
from support_functions import data_loader
importlib.reload(data_loader)
from support_functions.data_loader import load_data

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    build_entity_cash_flows
)

from support_functions import math_utils
importlib.reload(math_utils)
from support_functions.math_utils import (
    xirr
)

# %%
data = load_data(data_dir)
transactions_df = data.transactions
positions_df = data.positions
latest_date = data.latest_date
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
account_num = "Z23390746"
entity_name = "912797RJ8" # AAPL & FXAIX & 912797SZ1 & 912797RJ8

entity_cash_flows = build_entity_cash_flows(data, account_num, entity_name)

# %%
cash_flows = entity_cash_flows.cash_flows
total_invested = entity_cash_flows.total_invested
current_value = entity_cash_flows.current_value
current_basis = entity_cash_flows.current_basis
latest_date = entity_cash_flows.latest_date

# %%
discount_rate=0.045

# %%
times = []
pvs = []

for date, amount in cash_flows:
    t = (date - cash_flows[0][0]).days / 365.0
    pv = amount * np.exp(-discount_rate * t)
    
    times.append(t)
    pvs.append(pv)

abs_pvs = np.abs(pvs)
total_pv = np.sum(abs_pvs)

# if total_pv == 0: return 0

mac_duration = np.sum(np.array(times) * abs_pvs) / total_pv
mac_duration
# Out:
# np.float64(0.06024086370048307)

# %%
invested_cash_flows = [flow for flow in cash_flows if flow[1] < 0]
dates, amounts = zip(*invested_cash_flows)
amounts = pd.Series(amounts)
amounts_ratio = amounts/amounts.sum()
holding_period = pd.Series([(latest_date - d).days for d in dates])
(amounts_ratio*holding_period).sum()/365.0
# Out:
# np.float64(0.1643835616438356)

# %%
dates, amounts = zip(*cash_flows)
amounts = pd.Series(amounts)

# 计算绝对投入总额（分母通常使用总流出，即总成本）
total_outflow = abs(amounts[amounts < 0].sum())


# 计算每一笔现金流距离结算日的天数
# 注意：这里的 amounts 包含正负值
holding_days = pd.Series([(latest_date - d).days for d in dates])

# (金额 * 天数) 的总和 / 总投入成本
# 负向现金流产生的“持有天数”会被正向现金流（卖出）抵消
weighted_days = (amounts * holding_days).sum()

# 因为流入是正，流出是负，所以结果通常是负数，取绝对值
abs(weighted_days / total_outflow) / 365.0
# Out:
# np.float64(0.12035789963026547)

# %% [markdown]
# # PortfolioAnalyzer

# %%
from support_functions import portfolio_analyzer
importlib.reload(portfolio_analyzer)
from support_functions.portfolio_analyzer import PortfolioAnalyzer

# %%
analyzer = PortfolioAnalyzer(data_dir, output_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %% [markdown]
# ## analyze_entity_in_account

# %%
from support_functions import portfolio_analyzer
importlib.reload(portfolio_analyzer)
from support_functions.portfolio_analyzer import (
    PortfolioAnalyzer,
)

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    build_entity_cash_flows,
)

from support_functions import math_utils
importlib.reload(math_utils)
from support_functions.math_utils import (
    calculate_metrics,
)

analyzer = PortfolioAnalyzer(data_dir, output_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.
# /Users/yifanli/Github/fidelity-portfolio-tracker/src/support_functions/data_loader.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactions_df['Symbol'] = transactions_df['Description'].map(symbol_map).fillna(transactions_df.get('Symbol', None))

# %%
account_num, entity_name = test_case_pair[8]
data = analyzer.data
transactions = data.transactions
position = data.positions
account_name = data.account_map.get(account_num, "Unknown")

# %%
entity_cash_flows = build_entity_cash_flows(data, account_num, entity_name)

# %%
metrics = calculate_metrics(entity_cash_flows)

# %%
result = pd.Series({
    'Account Number': account_num,
    'Account Name': account_name,
    'Entity Name': entity_name,
    'Total Invested': entity_cash_flows.total_invested,
    'Current Basis': entity_cash_flows.current_basis,
    'Current Value': entity_cash_flows.current_value,
    'Total PnL': metrics['Total PnL'],
    'IRR (%)': f"{metrics['IRR']:.2%}" if metrics['IRR'] is not None else "N/A",
    'Total Return (%)': f"{metrics['ROI']:.2%}",
    'Holding Period (Y)': f"{metrics['Holding Period (Y)']:.2f}"
})
result
# Out:
# Account Number                     241802439
# Account Name          Health Savings Account
# Entity Name                            FXAIX
# Total Invested                       3560.87
# Current Basis                        3560.87
# Current Value                        4293.61
# Total PnL                             794.61
# IRR (%)                               16.81%
# Total Return (%)                      22.32%
# Holding Period (Y)                      1.29
# dtype: object

# %%
pd.DataFrame(entity_cash_flows.cash_flows).to_csv("/Users/yifanli/Github/fidelity-portfolio-tracker/data/temp.csv")

# %%
transactions[transactions['Account Number'] == '86964']
# Out:
#       Run Date               Account Account Number             Action  \
# 294 2024-01-26  ERNST & YOUNG 401(K)          86964      Contributions
# 295 2024-01-26  ERNST & YOUNG 401(K)          86964      Contributions
# 284 2024-02-09  ERNST & YOUNG 401(K)          86964      Contributions
# 283 2024-02-09  ERNST & YOUNG 401(K)          86964      Contributions
# 277 2024-02-23  ERNST & YOUNG 401(K)          86964      Contributions
# ..         ...                   ...            ...                ...
# 700 2026-01-02  ERNST & YOUNG 401(K)          86964  RECORDKEEPING FEE
# 690 2026-01-09  ERNST & YOUNG 401(K)          86964      Contributions
# 691 2026-01-09  ERNST & YOUNG 401(K)          86964      Contributions
# 679 2026-01-23  ERNST & YOUNG 401(K)          86964      Contributions
# 678 2026-01-23  ERNST & YOUNG 401(K)          86964      Contributions
#
#         Symbol           Description Type  Price ($)  Quantity  \
# 294      FBCGX   FID BLUE CHIP GR K6  NaN      3.716       0.0
# 295  84679P173  SP 500 INDEX PL CL E  NaN      1.070       0.0
# 284  84679P173  SP 500 INDEX PL CL E  NaN      1.041       0.0
# 283      FBCGX   FID BLUE CHIP GR K6  NaN      3.542       0.0
# 277  84679P173  SP 500 INDEX PL CL E  NaN      1.027       0.0
# ..         ...                   ...  ...        ...       ...
# 700      FBCGX   FID BLUE CHIP GR K6  NaN     -0.030       0.0
# 690      FBCGX   FID BLUE CHIP GR K6  NaN      3.049       0.0
# 691  84679P173  SP 500 INDEX PL CL F  NaN      0.964       0.0
# 679  84679P173  SP 500 INDEX PL CL F  NaN      0.970       0.0
# 678      FBCGX   FID BLUE CHIP GR K6  NaN      3.085       0.0
#
#      Commission ($)  Fees ($)  Accrued Interest ($)  Amount ($)  \
# 294             0.0       0.0                   0.0      103.85
# 295             0.0       0.0                   0.0      242.30
# 284             0.0       0.0                   0.0      242.30
# 283             0.0       0.0                   0.0      103.85
# 277             0.0       0.0                   0.0      242.30
# ..              ...       ...                   ...         ...
# 700             0.0       0.0                   0.0       -1.32
# 690             0.0       0.0                   0.0      136.71
# 691             0.0       0.0                   0.0      318.98
# 679             0.0       0.0                   0.0      318.98
# 678             0.0       0.0                   0.0      136.71
#
#     Settlement Date Asset Type
# 294             NaT      Stock
# 295             NaT      Stock
# 284             NaT      Stock
# 283             NaT      Stock
# 277             NaT      Stock
# ..              ...        ...
# 700             NaT      Stock
# 690             NaT      Stock
# 691             NaT      Stock
# 679             NaT      Stock
# 678             NaT      Stock
#
# [149 rows x 15 columns]

# %% [markdown]
# ## analyze_all_entities_in_account

# %%
from support_functions import portfolio_analyzer
importlib.reload(portfolio_analyzer)
from support_functions.portfolio_analyzer import (
    PortfolioAnalyzer,
)

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    build_entity_cash_flows,
)

from support_functions import math_utils
importlib.reload(math_utils)
from support_functions.math_utils import (
    calculate_metrics,
)

analyzer = PortfolioAnalyzer(data_dir, output_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
account_num, entity_name = test_case_pair[0]
data = analyzer.data
transactions = data.transactions
position = data.positions
account_name = data.account_map.get(account_num, "Unknown")

# %%
results = []
sub_transactions = data.transactions[data.transactions['Account Number'] == account_num]
entity_name_list = sub_transactions['Symbol'].unique()
entity_name_list = entity_name_list[entity_name_list != '']
entity_name_list
# Out:
# array(['FZFXX', 'AAPL', 'SBUX', 'JPM', 'AXP', 'GOOGL', 'AMZN', 'NKE',
#        '912797JK4', '912797LL9', '912797GZ4', '912797GN1', '912797HG5',
#        'TSLA', 'FXAIX', '912797HQ3', '912797HT7', 'MCD', '912797GB7',
#        '912797HS9', '912797JT5', '912797KV8', '912797JU2', '912797KB2',
#        '912797KC0', 'FSKAX', 'FSPSX', 'COKE', 'MSFT', '912797KL0',
#        '912797LH8', '912797KA4', '912797LE5', '912797GW1', '912797HP5',
#        '912797KT3', '912797LC9', '912797LR6', '912797LX3', '912797MB0',
#        '912797LY1', 'BRKB', '912797LZ8', '912797LP0', '912796ZV4', 'KHC',
#        '912797MX2', 'VZ', '912797KJ5', '912797NB9', '912797PJ0',
#        '912797MM6', 'NVDA', '912797ND5', '912797NK9', 'PEP', '912797PT8',
#        '912797NC7', '912797NZ6', '912797NE3', '912797NN3', '912797LN5',
#        '912797NV5', '912797QA8', '912797QB6', '912797QH3', '912797PW1',
#        '912797PG6', '912797MG9', '912797QL4', '912797QU4', 'PG', 'COST',
#        '912797QT7', '912797NA1', '912797QW0', '912797RD1', '912797RM1',
#        '912797QG5', '912797RN9', '912797RQ2', '912797RX7', '912797QS9',
#        'GLD', '912797QY6', '912797RZ2', '912797SE8', '912797RA7',
#        '912797SG3', '912797RY5', '912797RJ8', '912797SQ1', '912797SS7',
#        '912797ST5', '912797SY4', '912797RU3', '912797SR9', '912797SZ1'],
#       dtype=object)

# %%
for entity_name in entity_name_list:
    result = analyzer.analyze_entity_in_account(account_num, entity_name)
    results.append(result)

# %%
pd.DataFrame(results)
# Out:
#    Account Number Account Name Entity Name  Total Invested  Current Basis  \
# 0       Z23390746   Individual       FZFXX         6659.36           0.00
# 1       Z23390746   Individual        AAPL        15994.99       15994.99
# 2       Z23390746   Individual        SBUX         2453.40        2453.40
# 3       Z23390746   Individual         JPM         1200.00        1200.00
# 4       Z23390746   Individual         AXP         1500.00        1500.00
# ..            ...          ...         ...             ...            ...
# 93      Z23390746   Individual   912797ST5        99443.11       99443.11
# 94      Z23390746   Individual   912797SY4        99449.33       99449.33
# 95      Z23390746   Individual   912797RU3        99581.75       99581.75
# 96      Z23390746   Individual   912797SR9        99720.39       99720.39
# 97      Z23390746   Individual   912797SZ1        99440.00       99440.00
#
#     Current Value  Total PnL IRR (%) Total Return (%) Holding Period (Y)
# 0             0.0       0.00     N/A            0.00%               0.00
# 1         23353.2    7577.61  17.20%           47.37%               2.28
# 2          2758.5     495.50   6.77%           20.20%               2.89
# 3          3058.9    2025.90  34.36%          168.82%               3.45
# 4          3521.7    2108.70  29.78%          140.58%               3.42
# ..            ...        ...     ...              ...                ...
# 93        99708.0     264.89   3.18%            0.27%               0.08
# 94        99638.0     188.67   3.05%            0.19%               0.06
# 95        99759.0     177.25   3.67%            0.18%               0.05
# 96        99849.0     128.61   2.98%            0.13%               0.04
# 97        99566.0     126.00   2.93%            0.13%               0.04
#
# [98 rows x 10 columns]

# %%
account_num, entity_name = test_case_pair[0]
analyzer.analyze_all_entities_in_account(account_num).head(20)
# Out:
#    Account Number Account Name Entity Name  Total Invested  Current Basis  \
# 14      Z23390746   Individual       FXAIX       142563.94      142563.94
# 25      Z23390746   Individual       FSKAX       102299.89      102299.89
# 91      Z23390746   Individual   912797SQ1        99438.44       99438.44
# 96      Z23390746   Individual   912797SR9        99720.39       99720.39
# 92      Z23390746   Individual   912797SS7        99442.33       99442.33
# 95      Z23390746   Individual   912797RU3        99581.75       99581.75
# 93      Z23390746   Individual   912797ST5        99443.11       99443.11
# 94      Z23390746   Individual   912797SY4        99449.33       99449.33
# 97      Z23390746   Individual   912797SZ1        99440.00       99440.00
# 26      Z23390746   Individual       FSPSX        63994.40       63994.40
# 1       Z23390746   Individual        AAPL        15994.99       15994.99
# 83      Z23390746   Individual         GLD        12270.00       12270.00
# 13      Z23390746   Individual        TSLA         8217.50        8217.50
# 28      Z23390746   Individual        MSFT        13342.95       13342.95
# 5       Z23390746   Individual       GOOGL         4960.00        4960.00
# 41      Z23390746   Individual        BRKB         9230.90        9230.90
# 17      Z23390746   Individual         MCD         5157.50        5157.50
# 4       Z23390746   Individual         AXP         1500.00        1500.00
# 3       Z23390746   Individual         JPM         1200.00        1200.00
# 27      Z23390746   Individual        COKE         2175.00        2175.00
#
#     Current Value  Total PnL  IRR (%) Total Return (%) Holding Period (Y)  \
# 14      180710.35   40710.35   21.96%           28.56%               1.26
# 25      124876.18   24876.18   16.90%           24.32%               1.40
# 91       99921.00     482.56    3.53%            0.49%               0.14
# 96       99849.00     128.61    2.98%            0.13%               0.04
# 92       99779.00     336.67    3.30%            0.34%               0.10
# 95       99759.00     177.25    3.67%            0.18%               0.05
# 93       99708.00     264.89    3.18%            0.27%               0.08
# 94       99638.00     188.67    3.05%            0.19%               0.06
# 97       99566.00     126.00    2.93%            0.13%               0.04
# 26       80807.45   20807.45   20.37%           32.51%               1.54
# 1        23353.20    7577.61   17.20%           47.37%               2.28
# 83       13348.50    1078.50  100.70%            8.79%               0.12
# 13       12912.30    4694.80   48.76%           57.13%               0.95
# 28       12908.70    -284.85   -1.39%           -2.13%               1.55
# 5        10140.00    5208.60   57.42%          105.01%               1.13
# 41        9610.60     379.70    4.66%            4.11%               0.88
# 17        6300.00    1371.40   15.09%           26.59%               1.71
# 4         3521.70    2108.70   29.78%          140.58%               3.42
# 3         3058.90    2025.90   34.36%          168.82%               3.45
# 27        3041.20    2924.94   96.76%          134.48%               1.57
#
#    Investment Ratio
# 14           15.06%
# 25           10.40%
# 91            8.32%
# 96            8.32%
# 92            8.31%
# 95            8.31%
# 93            8.31%
# 94            8.30%
# 97            8.29%
# 26            6.73%
# 1             1.95%
# 83            1.11%
# 13            1.08%
# 28            1.08%
# 5             0.84%
# 41            0.80%
# 17            0.52%
# 4             0.29%
# 3             0.25%
# 27            0.25%

# %% [markdown]
# ## analyze_account_by_asset_class

# %%
from support_functions import portfolio_analyzer
importlib.reload(portfolio_analyzer)
from support_functions.portfolio_analyzer import (
    PortfolioAnalyzer,
)

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    build_asset_class_cash_flows,
)

from support_functions import math_utils
importlib.reload(math_utils)
from support_functions.math_utils import (
    calculate_metrics,
)

analyzer = PortfolioAnalyzer(data_dir, output_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
account_num, entity_name = test_case_pair[0]
data = analyzer.data
account_name = data.account_map.get(account_num, "Unknown")


asset_class = "Stock"

# %%
asset_class_cash_flows = build_asset_class_cash_flows(analyzer.data, account_num, asset_class)
metrics = calculate_metrics(asset_class_cash_flows)

# %%
result = pd.Series({
    'Account Number': account_num,
    'Account Name': account_name,
    'Asset Type': asset_class,
    'Total Invested': asset_class_cash_flows.total_invested,
    'Current Basis': asset_class_cash_flows.current_basis,
    'Current Value': asset_class_cash_flows.current_value,
    'Total PnL': metrics['Total PnL'],
    'IRR (%)': f"{metrics['IRR']:.2%}" if metrics['IRR'] is not None else "N/A",
    'Total Return (%)': f"{metrics['ROI']:.2%}",
    'Holding Period (Y)': f"{metrics['Holding Period (Y)']:.2f}"
})
result
# Out:
# Account Number         Z23390746
# Account Name          Individual
# Asset Type                 Stock
# Total Invested         399361.27
# Current Basis          399361.27
# Current Value          502149.93
# Total PnL              115320.95
# IRR (%)                   19.97%
# Total Return (%)          28.88%
# Holding Period (Y)          1.37
# dtype: object

# %%
funding_cash_flows = build_asset_class_cash_flows(data, account_num, 'Transfer')
total_funding = sum(amount for date, amount in funding_cash_flows.cash_flows)
total_funding-696515.35-399361.27
# Out:
# np.float64(4123.380000000005)

# %%
cash_cash_flows = build_asset_class_cash_flows(data, account_num, 'Cash')

# %%
cash_cash_flows.total_invested
# Out:
# 6659.359999999999

# %%
account_num, entity_name = test_case_pair[0]
analyzer.analyze_account_by_asset_class(account_num).head(20)
# Out:
#   Account Number Account Name Asset Class  Total Invested  Current Basis  \
# 1      Z23390746   Individual        Bond      6333956.10      696515.35
# 0      Z23390746   Individual       Stock       399361.27      399361.27
# 2      Z23390746   Individual        Cash         6659.36        4123.38
#
#    Current Value  Total PnL IRR (%) Total Return (%) Holding Period (Y)  \
# 1      698220.00   40263.90   4.23%            0.64%               0.69
# 0      502149.93  115320.95  19.97%           28.88%               1.37
# 2       59792.04        NaN    None             None               None
#
#   Investment Ratio
# 1           55.41%
# 0           39.85%
# 2            4.74%

# %% [markdown]
# ## analyze_account_performance

# %%
from support_functions import portfolio_analyzer
importlib.reload(portfolio_analyzer)
from support_functions.portfolio_analyzer import (
    PortfolioAnalyzer,
)

from support_functions import flow_builders
importlib.reload(flow_builders)
from support_functions.flow_builders import (
    build_account_cash_flows,
)

from support_functions import math_utils
importlib.reload(math_utils)
from support_functions.math_utils import (
    calculate_metrics,
)

analyzer = PortfolioAnalyzer(data_dir, output_dir)
# Out:
# Loading positions from: /Users/yifanli/Github/fidelity-portfolio-tracker/data/Portfolio_Positions_Jan-31-2026.csv (Date: 2026-01-31)
# Found 5 history files.

# %%
unique_accounts = analyzer.data.unique_accounts
results = []
        
for _, row in unique_accounts.iterrows():
    account_name = row['Account Name']
    account_num = row['Account Number']
    account_cash_flows = build_account_cash_flows(analyzer.data, account_num)
    metrics = calculate_metrics(account_cash_flows)

    results.append({
        'Account Name': account_name,
        'Account Number': account_num,
        'Total Invested': account_cash_flows.total_invested,
        'Current Basis': account_cash_flows.current_basis,
        'Current Value': account_cash_flows.current_value,
        'Total PnL': metrics['Total PnL'],
        'IRR': f"{metrics['IRR']:.2%}" if metrics['IRR'] is not None else "N/A",
        'Total Return (%)': f"{metrics['ROI']:.2%}",
        'Holding Period (Y)': f"{metrics['Holding Period (Y)']:.2f}"
    })

results = pd.DataFrame(results)
if not results.empty and 'Total Invested' in results.columns:
    ratio = results['Total Invested'] / results['Total Invested'].sum()
    results['Investment Ratio'] = ratio.apply(lambda x: f"{x:.2%}")
    results.sort_values('Total Invested', ascending=False)

# %%
results.sort_values('Total Invested', ascending=False)
# Out:
#                    Account Name Account Number  Total Invested  Current Basis  \
# 0                    Individual      Z23390746      1100000.00     1095876.62
# 1          ERNST & YOUNG 401(K)          86964        25721.51       28204.63
# 3        Health Savings Account      241802439         8787.30        7397.01
# 2  Cash Management (Individual)      Z06872898          100.00           0.00
#
#    Current Value  Total PnL     IRR Total Return (%) Holding Period (Y)  \
# 0     1260161.97  160161.97   9.85%           14.56%               1.51
# 1       30398.24    4676.73  20.99%           18.18%               0.84
# 3       10353.35    1566.05  17.03%           17.82%               1.02
# 2         108.34      16.68   4.73%           16.68%               0.00
#
#   Investment Ratio
# 0           96.95%
# 1            2.27%
# 3            0.77%
# 2            0.01%
