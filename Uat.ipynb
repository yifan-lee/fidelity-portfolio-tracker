# %%
import pandas as pd
import numpy as np
import os
import importlib
from datetime import datetime,date
import glob

# %%
from support_functions_Uat.display_percentage import display_percentage
from support_functions_Uat.data_loader import load_position, load_transaction
from support_functions_Uat.portfolio import Portfolio

# %%
data_folder_path = "./data"
transaction_file_pattern = "Accounts_History_*.csv"
position_file_pattern = "Portfolio_Positions_*.csv"

transactions = load_transaction(data_folder_path, transaction_file_pattern)
position = load_position(data_folder_path, position_file_pattern)
# Out:
# The latest transaction date is 2025-08-05

# %%
portfolio = Portfolio(transactions=transactions, position=position)

# %%
result = portfolio.get_individual_account_summary()
display_percentage(result,['Percentage','IRR'])
# Out:
#     Type       Value Percentage     IRR  Weighted Avg Holding Period
# 0   bond   746743.50     62.47%   4.38%                     6.080016
# 1  stock   423303.14     35.41%  16.32%                    12.135459
# 2   cash    25294.19      2.12%    nan%                    10.206035
# 3  Total  1195340.83    100.00%   8.70%                     6.619799

# %%
result = portfolio.get_all_stock_summary()
display_percentage(result,['Percentage','IRR'])
# Out:
#    Symbol  Current Value Percentage      IRR  Weighted Avg Holding Period
# 21  Total      423303.14    100.00%   16.32%                    12.135459
# 8   FXAIX      163865.08     38.71%   19.64%                     9.488276
# 11  FSKAX      113381.14     26.78%   13.48%                    11.242673
# 10  FSPSX       69497.82     16.42%   13.18%                    13.407668
# 13   MSFT       15867.00      3.75%   17.02%                    12.858178
# 0    AAPL       14233.47      3.36%   10.25%                    34.964264
# 7    TSLA        6193.40      1.46%   32.69%                    18.500730
# 9     MCD        6013.60      1.42%   14.91%                    14.802488
# 14   BRKB        4661.80      1.10%    1.70%                     9.566667
# 4   GOOGL        3888.10      0.92%   30.99%                    29.833880
# 3     AXP        2981.20      0.70%   24.59%                    35.633333
# 2     JPM        2915.42      0.69%   32.36%                    36.066667
# 15    KHC        2708.00      0.64%  -17.44%                     8.800000
# 1    SBUX        2707.05      0.64%    6.54%                    29.161930
# 12   COKE        2248.80      0.53%   68.96%                    13.184674
# 6     NKE        2230.05      0.53%   -7.13%                    20.010250
# 16     VZ        2140.25      0.51%   10.35%                     7.833333
# 5    AMZN        2136.90      0.50%   33.02%                    29.866667
# 17   NVDA        1785.50      0.42%   79.59%                     6.333333
# 19     PG        1507.00      0.36%  -55.36%                     0.900000
# 18    PEP        1394.80      0.33%   -2.55%                     5.866667
# 20   COST         946.76      0.22%  -46.65%                     0.900000

# %%
result = portfolio.get_all_bond_summary()
display_percentage(result,['Percentage','IRR'])
# Out:
#        Symbol  Current Value Percentage    IRR  Weighted Avg Holding Period
# 54      Total       746743.5    100.00%  4.38%                     6.080016
# 46  912797PW1       149338.5     20.00%  3.87%                     0.786740
# 50  912797QU4       149253.0     19.99%  3.50%                     0.866283
# 48  912797MG9        99976.0     13.39%  4.28%                     1.400000
# 49  912797QL4        99751.0     13.36%  3.98%                     1.333333
# 51  912797QT7        99586.0     13.34%  3.54%                     0.866667
# 53  912797QW0        99336.0     13.30%  0.24%                     0.166667
# 52  912797NA1        49503.0      6.63%  3.53%                     0.266667
# 33  912797MM6            0.0      0.00%  4.12%                     6.533333
# 36  912797PT8            0.0      0.00%  4.02%                     4.140923
# 35  912797NK9            0.0      0.00%  3.66%                     6.233333
# 34  912797ND5            0.0      0.00%  4.13%                     5.775662
# 30  912797KJ5            0.0      0.00%  4.17%                     6.897571
# 32  912797PJ0            0.0      0.00%  4.09%                     6.733333
# 31  912797NB9            0.0      0.00%  4.14%                     6.425058
# 38  912797NZ6            0.0      0.00%  3.64%                     4.833333
# 37  912797NC7            0.0      0.00%  4.11%                     4.900000
# 42  912797NV5            0.0      0.00%  4.11%                     3.033333
# 39  912797NE3            0.0      0.00%  4.10%                     4.433333
# 40  912797NN3            0.0      0.00%  3.71%                     3.221698
# 41  912797LN5            0.0      0.00%  4.10%                     3.266667
# 28  912796ZV4            0.0      0.00%  4.42%                     8.866667
# 43  912797QA8            0.0      0.00%  3.95%                     2.733333
# 44  912797QB6            0.0      0.00%  3.95%                     2.500000
# 45  912797QH3            0.0      0.00%  3.95%                     2.033333
# 47  912797PG6            0.0      0.00%  3.96%                     1.633333
# 29  912797MX2            0.0      0.00%  4.17%                     8.800000
# 0   912797JK4            0.0      0.00%  5.25%                    20.066667
# 1   912797LL9            0.0      0.00%  5.20%                    19.866667
# 13  912797KC0            0.0      0.00%  5.18%                    14.733333
# 2   912797GN1            0.0      0.00%  5.14%                    19.366667
# 3   912797GZ4            0.0      0.00%  5.24%                    19.366667
# 4   912797HG5            0.0      0.00%  5.16%                    18.700000
# 5   912797HQ3            0.0      0.00%  5.17%                    18.233333
# 6   912797HT7            0.0      0.00%  5.18%                    17.300000
# 7   912797GB7            0.0      0.00%  5.16%                    16.133333
# 8   912797HS9            0.0      0.00%  5.13%                    15.866667
# 9   912797KV8            0.0      0.00%  5.20%                    14.983292
# 10  912797JT5            0.0      0.00%  5.19%                    15.666667
# 11  912797JU2            0.0      0.00%  5.19%                    15.433333
# 12  912797KB2            0.0      0.00%  5.19%                    14.966667
# 14  912797KL0            0.0      0.00%  5.12%                    12.133333
# 26  912797LZ8            0.0      0.00%  4.43%                     9.366667
# 15  912797LH8            0.0      0.00%  4.53%                    11.833333
# 16  912797LE5            0.0      0.00%  4.99%                    11.700000
# 17  912797KA4            0.0      0.00%  4.82%                    11.700000
# 18  912797GW1            0.0      0.00%  5.03%                    11.666667
# 19  912797HP5            0.0      0.00%  4.92%                    11.466667
# 20  912797KT3            0.0      0.00%  5.00%                    11.433333
# 21  912797LC9            0.0      0.00%  4.48%                    10.500000
# 22  912797LR6            0.0      0.00%  4.44%                    10.300000
# 23  912797LX3            0.0      0.00%  4.49%                    10.066667
# 24  912797MB0            0.0      0.00%  4.09%                     9.966667
# 25  912797LY1            0.0      0.00%  4.39%                     8.708815
# 27  912797LP0            0.0      0.00%  4.49%                     9.333333
