# %%
import pandas as pd
import numpy as np
import os
import importlib
from datetime import datetime,date
import glob

# %%
import support_functions_Uat.display_percentage
importlib.reload(support_functions_Uat.display_percentage)
from support_functions_Uat.display_percentage import display_percentage

import support_functions_Uat.data_loader
importlib.reload(support_functions_Uat.data_loader)
from support_functions_Uat.data_loader import load_position, load_transaction

import support_functions_Uat.portfolio
importlib.reload(support_functions_Uat.portfolio)
from support_functions_Uat.portfolio import Portfolio,IndividualPortfolio,PensionPortfolio,HSAPortfolio

# %%
data_folder_path = "./data"
transaction_file_pattern = "Accounts_History_*.csv"
position_file_pattern = "Portfolio_Positions_*.csv"
transactions = load_transaction(data_folder_path, transaction_file_pattern)
position = load_position(data_folder_path, position_file_pattern)
portfolio = Portfolio(transactions=transactions, position=position)
individualPortfolio = IndividualPortfolio(transactions, position)
pensionPortfolio = PensionPortfolio(transactions, position)
hsaPortfolio = HSAPortfolio(transactions, position)
# Out:
# The latest transaction date is 2025-08-05

# %%
result = individualPortfolio.get_account_summary()
display_percentage(result,['Percentage','IRR'])
# Out:
#     Type       Value Percentage     IRR  Weighted Avg Holding Period
# 0   bond   746743.50     62.47%   4.37%                     6.113349
# 1  stock   423303.14     35.41%  16.30%                    12.172148
# 2   cash    25294.19      2.12%    nan%                    10.239369
# 3  Total  1195340.83    100.00%   8.67%                     8.346246

# %%
result = individualPortfolio.get_all_stock_summary()
display_percentage(result,['Percentage','IRR'])
# Out:
#    Symbol  Current Value Percentage      IRR  Weighted Avg Holding Period
# 21  Total      423303.14    100.00%   16.30%                    12.172148
# 8   FXAIX      163865.08     38.71%   19.73%                     9.473456
# 11  FSKAX      113381.14     26.78%   13.44%                    11.276006
# 10  FSPSX       69497.82     16.42%   13.14%                    13.441002
# 13   MSFT       15867.00      3.75%   16.98%                    12.891512
# 0    AAPL       14233.47      3.36%   10.24%                    34.997598
# 7    TSLA        6193.40      1.46%   32.63%                    18.534063
# 9     MCD        6013.60      1.42%   14.87%                    14.835822
# 14   BRKB        4661.80      1.10%    1.69%                     9.600000
# 4   GOOGL        3888.10      0.92%   30.96%                    29.867213
# 3     AXP        2981.20      0.70%   24.57%                    35.666667
# 2     JPM        2915.42      0.69%   32.33%                    36.100000
# 15    KHC        2708.00      0.64%  -17.37%                     8.833333
# 1    SBUX        2707.05      0.64%    6.54%                    29.195264
# 12   COKE        2248.80      0.53%   68.87%                    13.218008
# 6     NKE        2230.05      0.53%   -7.12%                    20.043583
# 16     VZ        2140.25      0.51%   10.30%                     7.866667
# 5    AMZN        2136.90      0.50%   32.99%                    29.900000
# 17   NVDA        1785.50      0.42%   79.18%                     6.366667
# 19     PG        1507.00      0.36%  -53.39%                     0.933333
# 18    PEP        1394.80      0.33%   -2.53%                     5.900000
# 20   COST         946.76      0.22%  -44.98%                     0.933333

# %%
result = individualPortfolio.get_all_bond_summary()
display_percentage(result,['Percentage','IRR'])
# Out:
#        Symbol  Current Value Percentage    IRR  Weighted Avg Holding Period
# 54      Total       746743.5    100.00%  4.37%                     6.113349
# 46  912797PW1       149338.5     20.00%  3.71%                     0.820074
# 50  912797QU4       149253.0     19.99%  3.37%                     0.899616
# 48  912797MG9        99976.0     13.39%  4.18%                     1.433333
# 49  912797QL4        99751.0     13.36%  3.88%                     1.366667
# 51  912797QT7        99586.0     13.34%  3.41%                     0.900000
# 53  912797QW0        99336.0     13.30%  0.20%                     0.200000
# 52  912797NA1        49503.0      6.63%  3.14%                     0.300000

# %%
result = pensionPortfolio.get_all_stock_summary(colName='Description')
display_percentage(result,['Percentage','IRR'])
# Out:
#             Description  Current Value Percentage     IRR  \
# 2                 Total       18311.28    100.00%  19.40%
# 1  SP 500 INDEX PL CL E       12580.24     68.70%  17.09%
# 0   FID BLUE CHIP GR K6        5731.04     31.30%  24.56%
#
#    Weighted Avg Holding Period
# 2                     8.769103
# 1                     8.755419
# 0                     8.800821

# %%
result = hsaPortfolio.get_all_stock_summary(colName='Description')
display_percentage(result,['Percentage','IRR'])
# Out:
#                          Description  Current Value Percentage     IRR  \
# 1            FIDELITY 500 INDEX FUND        3418.04    100.00%  13.39%
# 2                              Total        3418.04    100.00%  13.42%
# 0  FIDELITY GOVERNMENT CASH RESERVES           0.00      0.00%    nan%
#
#    Weighted Avg Holding Period
# 1                    11.765406
# 2                    11.614520
# 0                     6.841510
